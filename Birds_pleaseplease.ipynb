# %% [markdown]
# # EfficientNet_b0, RAdam,lr = 0.01, image size = 224, learning rate scheduler, weight decay = 5e-5, data augmentation, dropout 0.3
# ### https://hipolarbear.tistory.com/19 참고

# %%
# importing all the libraries we need
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
import time
import random 
import pandas as pd
import torch
from torch import nn, cuda, optim
from torchvision import models,transforms,datasets
from torch.utils.data import DataLoader,random_split
from PIL import Image
import seaborn as sns
import torch.nn.functional as F

# %%
# !nvidia-smi
# Out:
# Wed Jun  8 23:14:59 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir ./dataset
# !unzip /content/drive/MyDrive/4-1/data/Bird.zip -d ./dataset
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: ./dataset/train/COLLARED ARACARI/166.jpg
#   inflating: ./dataset/train/CRIMSON SUNBIRD/166.jpg
#   inflating: ./dataset/train/DOUBLE EYED FIG PARROT/166.jpg
#   inflating: ./dataset/train/GREATOR SAGE GROUSE/166.jpg
#   inflating: ./dataset/train/CEDAR WAXWING/166.jpg
#   inflating: ./dataset/train/ABBOTTS BOOBY/166.jpg
#   inflating: ./dataset/train/ALEXANDRINE PARAKEET/166.jpg
#   inflating: ./dataset/train/SORA/166.jpg
#   inflating: ./dataset/train/AMERICAN AVOCET/166.jpg
#   inflating: ./dataset/train/STRAWBERRY FINCH/166.jpg
#   inflating: ./dataset/train/RED TAILED HAWK/166.jpg
#   inflating: ./dataset/train/INDIAN ROLLER/166.jpg
#   inflating: ./dataset/train/NORTHERN PARULA/166.jpg
#   inflating: ./dataset/train/BANANAQUIT/166.jpg
#   inflating: ./dataset/train/RED BEARDED BEE EATER/166.jpg
#   inflating: ./dataset/train/D-ARNAUDS BARBET/166.jpg
#   inflating: ./dataset/train/BLACK-THROATED SPARROW/166.jpg
#   inflating: ./dataset/train/MARABOU STORK/166.jpg
#   inflating: ./dataset/train/GOLDEN CHEEKED WARBLER/166.jpg
#   inflating: ./dataset/train/VIOLET GREEN SWALLOW/166.jpg
#   inflating: ./dataset/train/BANDED PITA/166.jpg
#   inflating: ./dataset/train/ABBOTTS BABBLER/166.jpg
#   inflating: ./dataset/train/DOUBLE BRESTED CORMARANT/166.jpg
#   inflating: ./dataset/train/FLAME TANAGER/166.jpg
#   inflating: ./dataset/train/RED FACED WARBLER/166.jpg
#   inflating: ./dataset/train/HARPY EAGLE/166.jpg
#   inflating: ./dataset/train/SATYR TRAGOPAN/166.jpg
#   inflating: ./dataset/train/GREEN MAGPIE/166.jpg
#   inflating: ./dataset/train/GLOSSY IBIS/167.jpg
#   inflating: ./dataset/train/SORA/167.jpg
#   inflating: ./dataset/train/CEDAR WAXWING/167.jpg
#   inflating: ./dataset/train/HAWFINCH/167.jpg
#   inflating: ./dataset/train/LITTLE AUK/167.jpg
#   inflating: ./dataset/train/BANDED BROADBILL/167.jpg
#   inflating: ./dataset/train/SWINHOES PHEASANT/167.jpg
#   inflating: ./dataset/train/VIOLET GREEN SWALLOW/167.jpg
#   inflating: ./dataset/train/D-ARNAUDS BARBET/167.jpg
#   inflating: ./dataset/train/SHOEBILL/167.jpg
#   inflating: ./dataset/train/BROWN THRASHER/19.jpg
#   inflating: ./dataset/train/SAND MARTIN/19.jpg
#   inflating: ./dataset/train/ROBIN/19.jpg
#   inflating: ./dataset/train/SCARLET IBIS/19.jpg
#   inflating: ./dataset/train/EASTERN MEADOWLARK/190.jpg
#   inflating: ./dataset/train/OYSTER CATCHER/190.jpg
#   inflating: ./dataset/train/SORA/190.jpg
#   inflating: ./dataset/train/D-ARNAUDS BARBET/190.jpg
#   inflating: ./dataset/train/WOOD DUCK/190.jpg
#   inflating: ./dataset/train/BANDED BROADBILL/190.jpg
#   inflating: ./dataset/train/HOUSE FINCH/190.jpg
#   inflating: ./dataset/train/DARK EYED JUNCO/190.jpg
#   inflating: ./dataset/train/RAZORBILL/190.jpg
# ...
#         Is a directory
# error:  cannot delete old ./dataset/train/ROADRUNNER
#         Is a directory
# error:  cannot delete old ./dataset/train/COCKATOO
#         Is a directory
# error:  cannot delete old ./dataset/train/COLLARED ARACARI
#         Is a directory
# error:  cannot delete old ./dataset/train/PEACOCK
#         Is a directory
# error:  cannot delete old ./dataset/train/COMMON FIRECREST
#         Is a directory
# error:  cannot delete old ./dataset/train/COMMON GRACKLE
#         Is a directory
# error:  cannot delete old ./dataset/train/PELICAN
#         Is a directory
# error:  cannot delete old ./dataset/train/COMMON HOUSE MARTIN
#         Is a directory
# error:  cannot delete old ./dataset/train/ROYAL FLYCATCHER
#         Is a directory
# error:  cannot delete old ./dataset/train/VIOLET TURACO
#         Is a directory
# error:  cannot delete old ./dataset/train/COMMON IORA
#         Is a directory
# error:  cannot delete old ./dataset/train/COMMON LOON
#         Is a directory
# error:  cannot delete old ./dataset/train/COMMON POORWILL
#         Is a directory
# error:  cannot delete old ./dataset/train/COMMON STARLING
#         Is a directory
# error:  cannot delete old ./dataset/train/VIOLET GREEN SWALLOW
#         Is a directory
# error:  cannot delete old ./dataset/train/COPPERY TAILED COUCAL
#         Is a directory
# error:  cannot delete old ./dataset/train/CRAB PLOVER
#         Is a directory
# error:  cannot delete old ./dataset/train/CRANE HAWK
#         Is a directory
# error:  cannot delete old ./dataset/train/PEREGRINE FALCON
#         Is a directory
# error:  cannot delete old ./dataset/train/CREAM COLORED WOODPECKER
#         Is a directory
# error:  cannot delete old ./dataset/train/VICTORIA CROWNED PIGEON
#         Is a directory
# error:  cannot delete old ./dataset/train/CRESTED AUKLET
#         Is a directory
# error:  cannot delete old ./dataset/train/VERMILION FLYCATHER
#         Is a directory
# error:  cannot delete old ./dataset/train/CRESTED CARACARA
#         Is a directory
# error:  cannot delete old ./dataset/train/CRESTED COUA
#         Is a directory
# error:  cannot delete old ./dataset/train/VENEZUELIAN TROUPIAL
#         Is a directory
# error:  cannot delete old ./dataset/train/VARIED THRUSH
#         Is a directory
# error:  cannot delete old ./dataset/train/CRESTED FIREBACK
#         Is a directory
# error:  cannot delete old ./dataset/train/CRESTED KINGFISHER
#         Is a directory
# error:  cannot delete old ./dataset/train/CRESTED NUTHATCH
#         Is a directory
# error:  cannot delete old ./dataset/train/CRESTED OROPENDOLA
#         Is a directory
# error:  cannot delete old ./dataset/train/PHILIPPINE EAGLE
#         Is a directory
# error:  cannot delete old ./dataset/train/CRESTED SHRIKETIT
#         Is a directory
# error:  cannot delete old ./dataset/train/CRIMSON CHAT
#         Is a directory
# error:  cannot delete old ./dataset/train/CRIMSON SUNBIRD
#         Is a directory
# error:  cannot delete old ./dataset/train/CROW
#         Is a directory
# error:  cannot delete old ./dataset/train/PINK ROBIN
#         Is a directory
# error:  cannot delete old ./dataset/train/CROWNED PIGEON
#         Is a directory
# error:  cannot delete old ./dataset/train/CUBAN TODY
#         Is a directory
# error:  cannot delete old ./dataset/train/CUBAN TROGON
#         Is a directory
# error:  cannot delete old ./dataset/train/POMARINE JAEGER
#         Is a directory
# error:  cannot delete old ./dataset/train/SANDHILL CRANE
#         Is a directory
# error:  cannot delete old ./dataset/train/CURL CRESTED ARACURI
#         Is a directory
# error:  cannot delete old ./dataset/train/D-ARNAUDS BARBET
#         Is a directory
# error:  cannot delete old ./dataset/train/DARK EYED JUNCO
#         Is a directory
# error:  cannot delete old ./dataset/train/DEMOISELLE CRANE
#         Is a directory
# error:  cannot delete old ./dataset/train/DOUBLE BARRED FINCH
#         Is a directory
# error:  cannot delete old ./dataset/train/UMBRELLA BIRD
#         Is a directory
# error:  cannot delete old ./dataset/train/DOUBLE BRESTED CORMARANT
#         Is a directory
# error:  cannot delete old ./dataset/train/DOUBLE EYED FIG PARROT
#         Is a directory
# error:  cannot delete old ./dataset/train/TURQUOISE MOTMOT
#         Is a directory
# error:  cannot delete old ./dataset/train/SAND MARTIN
#         Is a directory
# error:  cannot delete old ./dataset/train/DOWNY WOODPECKER
#         Is a directory
# error:  cannot delete old ./dataset/train/DUSKY LORY
#         Is a directory
# error:  cannot delete old ./dataset/train/EARED PITA
#         Is a directory
# error:  cannot delete old ./dataset/train/EASTERN BLUEBIRD
#         Is a directory
# error:  cannot delete old ./dataset/train/PUFFIN
#         Is a directory
# error:  cannot delete old ./dataset/train/PURPLE FINCH
#         Is a directory
# error:  cannot delete old ./dataset/train/EASTERN GOLDEN WEAVER
#         Is a directory
# error:  cannot delete old ./dataset/train/EASTERN MEADOWLARK
#         Is a directory
# error:  cannot delete old ./dataset/train/EASTERN ROSELLA
#         Is a directory
# error:  cannot delete old ./dataset/train/EASTERN TOWEE
#         Is a directory
# error:  cannot delete old ./dataset/train/PURPLE GALLINULE
#         Is a directory
# error:  cannot delete old ./dataset/train/TURKEY VULTURE
#         Is a directory
# error:  cannot delete old ./dataset/train/ELEGANT TROGON
#         Is a directory
# error:  cannot delete old ./dataset/train/ELLIOTS  PHEASANT
#         Is a directory
# error:  cannot delete old ./dataset/train/EMERALD TANAGER
#         Is a directory
# error:  cannot delete old ./dataset/train/TRUMPTER SWAN
#         Is a directory
# error:  cannot delete old ./dataset/train/EMPEROR PENGUIN
#         Is a directory
# error:  cannot delete old ./dataset/train/EMU
#         Is a directory
# error:  cannot delete old ./dataset/train/ENGGANO MYNA
#         Is a directory
# error:  cannot delete old ./dataset/train/TROPICAL KINGBIRD
#         Is a directory
# error:  cannot delete old ./dataset/train/EURASIAN GOLDEN ORIOLE
#         Is a directory
# error:  cannot delete old ./dataset/train/EURASIAN MAGPIE
#         Is a directory
# error:  cannot delete old ./dataset/train/EUROPEAN GOLDFINCH
#         Is a directory
# error:  cannot delete old ./dataset/train/EUROPEAN TURTLE DOVE
#         Is a directory
# error:  cannot delete old ./dataset/train/TREE SWALLOW
#         Is a directory
# error:  cannot delete old ./dataset/train/EVENING GROSBEAK
#         Is a directory
# error:  cannot delete old ./dataset/train/TOWNSENDS WARBLER
#         Is a directory
# error:  cannot delete old ./dataset/train/FAIRY BLUEBIRD
#         Is a directory
# error:  cannot delete old ./dataset/train/FAIRY TERN
#         Is a directory
# error:  cannot delete old ./dataset/train/FIORDLAND PENGUIN
#         Is a directory
# error:  cannot delete old ./dataset/train/TOUCHAN
#         Is a directory
# error:  cannot delete old ./dataset/train/TIT MOUSE
#         Is a directory
# error:  cannot delete old ./dataset/train/PURPLE MARTIN
#         Is a directory
# error:  cannot delete old ./dataset/train/SAMATRAN THRUSH
#         Is a directory
# error:  cannot delete old ./dataset/train/FIRE TAILLED MYZORNIS
#         Is a directory
# error:  cannot delete old ./dataset/train/FLAME BOWERBIRD
#         Is a directory
# error:  cannot delete old ./dataset/train/TEAL DUCK
#         Is a directory
# error:  cannot delete old ./dataset/train/FLAME TANAGER
#         Is a directory
# error:  cannot delete old ./dataset/train/FLAMINGO
#         Is a directory
# error:  cannot delete old ./dataset/train/PURPLE SWAMPHEN
#         Is a directory
# error:  cannot delete old ./dataset/train/FRIGATE
#         Is a directory
# error:  cannot delete old ./dataset/train/GAMBELS QUAIL
#         Is a directory
# error:  cannot delete old ./dataset/train/GANG GANG COCKATOO
#         Is a directory
# error:  cannot delete old ./dataset/train/GILA WOODPECKER
#         Is a directory
# error:  cannot delete old ./dataset/train/GILDED FLICKER
#         Is a directory
# error:  cannot delete old ./dataset/train/PYGMY KINGFISHER
#         Is a directory
# error:  cannot delete old ./dataset/train/GLOSSY IBIS
#         Is a directory
# error:  cannot delete old ./dataset/train/GO AWAY BIRD
#         Is a directory
# error:  cannot delete old ./dataset/train/QUETZAL
#         Is a directory
# error:  cannot delete old ./dataset/train/GOLD WING WARBLER
#         Is a directory
# error:  cannot delete old ./dataset/train/GOLDEN CHEEKED WARBLER
#         Is a directory
# error:  cannot delete old ./dataset/train/TASMANIAN HEN
#         Is a directory
# error:  cannot delete old ./dataset/train/TAKAHE
#         Is a directory
# error:  cannot delete old ./dataset/train/TAIWAN MAGPIE
#         Is a directory
# error:  cannot delete old ./dataset/train/TAILORBIRD
#         Is a directory
# error:  cannot delete old ./dataset/train/GOLDEN CHLOROPHONIA
#         Is a directory
# error:  cannot delete old ./dataset/train/GOLDEN EAGLE
#         Is a directory
# error:  cannot delete old ./dataset/train/RUFUOS MOTMOT
#         Is a directory
# error:  cannot delete old ./dataset/train/GOLDEN PHEASANT
#         Is a directory
# error:  cannot delete old ./dataset/train/GOLDEN PIPIT
#         Is a directory
# error:  cannot delete old ./dataset/train/GOULDIAN FINCH
#         Is a directory
# error:  cannot delete old ./dataset/train/GRAY CATBIRD
#         Is a directory
# error:  cannot delete old ./dataset/train/SWINHOES PHEASANT
#         Is a directory
# error:  cannot delete old ./dataset/train/GRAY KINGBIRD
#         Is a directory
# error:  cannot delete old ./dataset/train/GRAY PARTRIDGE
#         Is a directory
# error:  cannot delete old ./dataset/train/SUPERB STARLING
#         Is a directory
# error:  cannot delete old ./dataset/train/GREAT GRAY OWL
#         Is a directory
# error:  cannot delete old ./dataset/train/GREAT JACAMAR
#         Is a directory
# error:  cannot delete old ./dataset/train/GREAT KISKADEE
#         Is a directory
# error:  cannot delete old ./dataset/train/STRIPPED SWALLOW
#         Is a directory
# error:  cannot delete old ./dataset/train/STRIPPED MANAKIN
#         Is a directory
# error:  cannot delete old ./dataset/train/GREAT POTOO
#         Is a directory
# error:  cannot delete old ./dataset/train/GREATOR SAGE GROUSE
#         Is a directory
# error:  cannot delete old ./dataset/train/GREEN BROADBILL
#         Is a directory
# error:  cannot delete old ./dataset/train/STRIPED OWL
#         Is a directory
# error:  cannot delete old ./dataset/train/GREEN JAY
#         Is a directory
# error:  cannot delete old ./dataset/train/GREEN MAGPIE
#         Is a directory
# error:  cannot delete old ./dataset/train/GREY PLOVER
#         Is a directory
# error:  cannot delete old ./dataset/train/GROVED BILLED ANI
#         Is a directory
# error:  cannot delete old ./dataset/train/STRAWBERRY FINCH
#         Is a directory
# error:  cannot delete old ./dataset/train/GUINEA TURACO
#         Is a directory
# error:  cannot delete old ./dataset/train/GUINEAFOWL
#         Is a directory
# error:  cannot delete old ./dataset/train/GURNEYS PITTA
#         Is a directory
# error:  cannot delete old ./dataset/train/STORK BILLED KINGFISHER
#         Is a directory
# error:  cannot delete old ./dataset/train/STEAMER DUCK
#         Is a directory
# error:  cannot delete old ./dataset/train/GYRFALCON
#         Is a directory
# error:  cannot delete old ./dataset/train/HAMMERKOP
#         Is a directory
# error:  cannot delete old ./dataset/train/HARLEQUIN DUCK
#         Is a directory
# error:  cannot delete old ./dataset/train/HARLEQUIN QUAIL
#         Is a directory
# error:  cannot delete old ./dataset/train/RUFOUS KINGFISHER
#         Is a directory
# error:  cannot delete old ./dataset/train/HARPY EAGLE
#         Is a directory
# error:  cannot delete old ./dataset/train/HAWAIIAN GOOSE
#         Is a directory
# error:  cannot delete old ./dataset/train/RAINBOW LORIKEET
#         Is a directory
# error:  cannot delete old ./dataset/train/HAWFINCH
#         Is a directory
# error:  cannot delete old ./dataset/train/HELMET VANGA
#         Is a directory
# error:  cannot delete old ./dataset/train/RAZORBILL
#         Is a directory
# error:  cannot delete old ./dataset/train/HEPATIC TANAGER
#         Is a directory
# error:  cannot delete old ./dataset/train/HIMALAYAN BLUETAIL
#         Is a directory
# error:  cannot delete old ./dataset/train/HIMALAYAN MONAL
#         Is a directory
# error:  cannot delete old ./dataset/train/RED BEARDED BEE EATER
#         Is a directory
# error:  cannot delete old ./dataset/train/HOATZIN
#         Is a directory
# error:  cannot delete old ./dataset/train/HOODED MERGANSER
#         Is a directory
# error:  cannot delete old ./dataset/train/ROBIN
#         Is a directory
# error:  cannot delete old ./dataset/train/RED BELLIED PITTA
#         Is a directory
# error:  cannot delete old ./dataset/train/HOOPOES
#         Is a directory
# error:  cannot delete old ./dataset/train/RED BROWED FINCH
#         Is a directory
# error:  cannot delete old ./dataset/train/HORNBILL
#         Is a directory
# error:  cannot delete old ./dataset/train/HORNED GUAN
#         Is a directory
# error:  cannot delete old ./dataset/train/HORNED LARK
#         Is a directory
# error:  cannot delete old ./dataset/train/ROCK DOVE
#         Is a directory
# error:  cannot delete old ./dataset/train/HORNED SUNGEM
#         Is a directory
# error:  cannot delete old ./dataset/train/SRI LANKA BLUE MAGPIE
#         Is a directory
# error:  cannot delete old ./dataset/train/HOUSE FINCH
#         Is a directory
# error:  cannot delete old ./dataset/train/HOUSE SPARROW
#         Is a directory
# error:  cannot delete old ./dataset/train/SPOTTED CATBIRD
#         Is a directory
# error:  cannot delete old ./dataset/train/HYACINTH MACAW
#         Is a directory
# error:  cannot delete old ./dataset/train/IBERIAN MAGPIE
#         Is a directory
# error:  cannot delete old ./dataset/train/IBISBILL
#         Is a directory
# error:  cannot delete old ./dataset/train/RED FACED CORMORANT
#         Is a directory
# error:  cannot delete old ./dataset/train/IMPERIAL SHAQ
#         Is a directory
# error:  cannot delete old ./dataset/train/INCA TERN
#         Is a directory
# error:  cannot delete old ./dataset/train/RED FACED WARBLER
#         Is a directory
# error:  cannot delete old ./dataset/train/INDIAN BUSTARD
#         Is a directory
# error:  cannot delete old ./dataset/train/INDIAN PITTA
#         Is a directory
# error:  cannot delete old ./dataset/train/SPOONBILL
#         Is a directory
# error:  cannot delete old ./dataset/train/INDIAN ROLLER
#         Is a directory
# error:  cannot delete old ./dataset/train/INDIGO BUNTING
#         Is a directory
# error:  cannot delete old ./dataset/train/INLAND DOTTEREL
#         Is a directory
# error:  cannot delete old ./dataset/train/IVORY GULL
#         Is a directory
# error:  cannot delete old ./dataset/train/SPOON BILED SANDPIPER
#         Is a directory
# error:  cannot delete old ./dataset/train/SPLENDID WREN
#         Is a directory
# error:  cannot delete old ./dataset/train/SPANGLED COTINGA
#         Is a directory
# error:  cannot delete old ./dataset/train/IWI
#         Is a directory
# error:  cannot delete old ./dataset/train/JABIRU
#         Is a directory
# error:  cannot delete old ./dataset/train/JACK SNIPE
#         Is a directory
# error:  cannot delete old ./dataset/train/RED FODY
#         Is a directory
# error:  cannot delete old ./dataset/train/RED HEADED DUCK
#         Is a directory
# error:  cannot delete old ./dataset/train/JANDAYA PARAKEET
#         Is a directory
# error:  cannot delete old ./dataset/train/JAPANESE ROBIN
#         Is a directory
# error:  cannot delete old ./dataset/train/JAVA SPARROW
#         Is a directory
# error:  cannot delete old ./dataset/train/RED HEADED WOODPECKER
#         Is a directory
# error:  cannot delete old ./dataset/train/KAGU
#         Is a directory
# error:  cannot delete old ./dataset/train/KAKAPO
#         Is a directory
# error:  cannot delete old ./dataset/train/ROSY FACED LOVEBIRD
#         Is a directory
# error:  cannot delete old ./dataset/train/KILLDEAR
#         Is a directory
# error:  cannot delete old ./dataset/train/KING VULTURE
#         Is a directory
# error:  cannot delete old ./dataset/train/RED HONEY CREEPER
#         Is a directory
# error:  cannot delete old ./dataset/train/ROUGH LEG BUZZARD
#         Is a directory

# %%
# data augmentation
import random
import numpy as np
import os
import cv2
import glob
from PIL import Image
import PIL.ImageOps    

num_augmented_images = 120

file_path = '/content/dataset/train/'
folder_names = os.listdir(file_path)
total_origin_folder_num = len(folder_names)
print(total_origin_folder_num) # 폴더 400개가 맞는지 확인

for k in range(total_origin_folder_num):
  folder_name = file_path + folder_names[k]
  file_names = os.listdir(folder_name)
  total_origin_image_num = len(file_names)
  augment_cnt = 1

  for i in range(num_augmented_images):
      file_name = file_names[i]
    
      origin_image_path = folder_name + '/' + file_name
      image = Image.open(origin_image_path)

      transform = transforms.Compose([transforms.RandomHorizontalFlip(p=1)])

      transform_image = transform(image)
      transform_image.save(folder_name + '/transform_' + str(augment_cnt) + '.jpg')

      augment_cnt += 1

  print(k+1, '번째 ', folder_name, '완료')
# Out:
# 400
# 1 번째  /content/dataset/train/INDIAN BUSTARD 완료
# 2 번째  /content/dataset/train/CLARKS NUTCRACKER 완료
# 3 번째  /content/dataset/train/SWINHOES PHEASANT 완료
# 4 번째  /content/dataset/train/RUBY THROATED HUMMINGBIRD 완료
# 5 번째  /content/dataset/train/CALIFORNIA GULL 완료
# 6 번째  /content/dataset/train/COCKATOO 완료
# 7 번째  /content/dataset/train/GOLD WING WARBLER 완료
# 8 번째  /content/dataset/train/COMMON FIRECREST 완료
# 9 번째  /content/dataset/train/ELEGANT TROGON 완료
# 10 번째  /content/dataset/train/NORTHERN CARDINAL 완료
# 11 번째  /content/dataset/train/BLACK COCKATO 완료
# 12 번째  /content/dataset/train/COMMON IORA 완료
# 13 번째  /content/dataset/train/ROSY FACED LOVEBIRD 완료
# 14 번째  /content/dataset/train/BLACK TAIL CRAKE 완료
# 15 번째  /content/dataset/train/GAMBELS QUAIL 완료
# 16 번째  /content/dataset/train/NORTHERN PARULA 완료
# 17 번째  /content/dataset/train/CRESTED AUKLET 완료
# 18 번째  /content/dataset/train/MALLARD DUCK 완료
# 19 번째  /content/dataset/train/INDIAN ROLLER 완료
# 20 번째  /content/dataset/train/HOUSE SPARROW 완료
# 21 번째  /content/dataset/train/RUFUOS MOTMOT 완료
# 22 번째  /content/dataset/train/HORNED GUAN 완료
# 23 번째  /content/dataset/train/BARROWS GOLDENEYE 완료
# 24 번째  /content/dataset/train/EVENING GROSBEAK 완료
# 25 번째  /content/dataset/train/AMERICAN KESTREL 완료
# 26 번째  /content/dataset/train/CRESTED NUTHATCH 완료
# 27 번째  /content/dataset/train/RED FODY 완료
# 28 번째  /content/dataset/train/FIORDLAND PENGUIN 완료
# 29 번째  /content/dataset/train/HORNBILL 완료
# 30 번째  /content/dataset/train/INLAND DOTTEREL 완료
# 31 번째  /content/dataset/train/GOULDIAN FINCH 완료
# 32 번째  /content/dataset/train/LITTLE AUK 완료
# 33 번째  /content/dataset/train/LESSER ADJUTANT 완료
# 34 번째  /content/dataset/train/DUSKY LORY 완료
# 35 번째  /content/dataset/train/INDIAN PITTA 완료
# 36 번째  /content/dataset/train/MANGROVE CUCKOO 완료
# 37 번째  /content/dataset/train/HARLEQUIN QUAIL 완료
# 38 번째  /content/dataset/train/NORTHERN RED BISHOP 완료
# 39 번째  /content/dataset/train/JAVA SPARROW 완료
# 40 번째  /content/dataset/train/GRAY KINGBIRD 완료
# 41 번째  /content/dataset/train/GOLDEN CHLOROPHONIA 완료
# 42 번째  /content/dataset/train/BLUE COAU 완료
# 43 번째  /content/dataset/train/ANDEAN SISKIN 완료
# 44 번째  /content/dataset/train/BORNEAN PHEASANT 완료
# 45 번째  /content/dataset/train/AMERICAN BITTERN 완료
# 46 번째  /content/dataset/train/RAZORBILL 완료
# 47 번째  /content/dataset/train/ENGGANO MYNA 완료
# 48 번째  /content/dataset/train/KOOKABURRA 완료
# 49 번째  /content/dataset/train/ALEXANDRINE PARAKEET 완료
# 50 번째  /content/dataset/train/GANG GANG COCKATOO 완료
# 51 번째  /content/dataset/train/SRI LANKA BLUE MAGPIE 완료
# 52 번째  /content/dataset/train/HORNED SUNGEM 완료
# 53 번째  /content/dataset/train/MASKED BOOBY 완료
# 54 번째  /content/dataset/train/TASMANIAN HEN 완료
# 55 번째  /content/dataset/train/ABBOTTS BABBLER 완료
# 56 번째  /content/dataset/train/VULTURINE GUINEAFOWL 완료
# 57 번째  /content/dataset/train/SCARLET IBIS 완료
# 58 번째  /content/dataset/train/WILSONS BIRD OF PARADISE 완료
# 59 번째  /content/dataset/train/VENEZUELIAN TROUPIAL 완료
# 60 번째  /content/dataset/train/BLUE HERON 완료
# 61 번째  /content/dataset/train/ABYSSINIAN GROUND HORNBILL 완료
# 62 번째  /content/dataset/train/CROW 완료
# 63 번째  /content/dataset/train/VIOLET GREEN SWALLOW 완료
# 64 번째  /content/dataset/train/BLACK SWAN 완료
# 65 번째  /content/dataset/train/PAINTED BUNTING 완료
# 66 번째  /content/dataset/train/ORIENTAL BAY OWL 완료
# 67 번째  /content/dataset/train/CRIMSON SUNBIRD 완료
# 68 번째  /content/dataset/train/GURNEYS PITTA 완료
# 69 번째  /content/dataset/train/BELTED KINGFISHER 완료
# 70 번째  /content/dataset/train/MANDRIN DUCK 완료
# 71 번째  /content/dataset/train/WHIMBREL 완료
# 72 번째  /content/dataset/train/SAMATRAN THRUSH 완료
# 73 번째  /content/dataset/train/WHITE NECKED RAVEN 완료
# 74 번째  /content/dataset/train/PALILA 완료
# 75 번째  /content/dataset/train/HARLEQUIN DUCK 완료
# 76 번째  /content/dataset/train/CUBAN TODY 완료
# 77 번째  /content/dataset/train/BALI STARLING 완료
# 78 번째  /content/dataset/train/CRESTED KINGFISHER 완료
# 79 번째  /content/dataset/train/TEAL DUCK 완료
# 80 번째  /content/dataset/train/OCELLATED TURKEY 완료
# 81 번째  /content/dataset/train/BLUE GROUSE 완료
# 82 번째  /content/dataset/train/BROWN NOODY 완료
# 83 번째  /content/dataset/train/FAIRY TERN 완료
# 84 번째  /content/dataset/train/ASIAN CRESTED IBIS 완료
# 85 번째  /content/dataset/train/AMERICAN REDSTART 완료
# 86 번째  /content/dataset/train/EASTERN MEADOWLARK 완료
# 87 번째  /content/dataset/train/SPANGLED COTINGA 완료
# 88 번째  /content/dataset/train/SNOWY EGRET 완료
# 89 번째  /content/dataset/train/INCA TERN 완료
# 90 번째  /content/dataset/train/AZURE JAY 완료
# 91 번째  /content/dataset/train/KIWI 완료
# 92 번째  /content/dataset/train/KILLDEAR 완료
# 93 번째  /content/dataset/train/CRESTED SHRIKETIT 완료
# 94 번째  /content/dataset/train/STRAWBERRY FINCH 완료
# 95 번째  /content/dataset/train/BALD EAGLE 완료
# 96 번째  /content/dataset/train/CAPUCHINBIRD 완료
# 97 번째  /content/dataset/train/VIOLET TURACO 완료
# 98 번째  /content/dataset/train/CEDAR WAXWING 완료
# 99 번째  /content/dataset/train/WOOD DUCK 완료
# 100 번째  /content/dataset/train/KAKAPO 완료
# 101 번째  /content/dataset/train/BARRED PUFFBIRD 완료
# 102 번째  /content/dataset/train/FLAME TANAGER 완료
# 103 번째  /content/dataset/train/ANDEAN GOOSE 완료
# 104 번째  /content/dataset/train/ORANGE BRESTED BUNTING 완료
# 105 번째  /content/dataset/train/HOATZIN 완료
# 106 번째  /content/dataset/train/TURKEY VULTURE 완료
# 107 번째  /content/dataset/train/PEREGRINE FALCON 완료
# 108 번째  /content/dataset/train/CAPPED HERON 완료
# 109 번째  /content/dataset/train/LARK BUNTING 완료
# 110 번째  /content/dataset/train/SHORT BILLED DOWITCHER 완료
# 111 번째  /content/dataset/train/ANNAS HUMMINGBIRD 완료
# 112 번째  /content/dataset/train/COMMON HOUSE MARTIN 완료
# 113 번째  /content/dataset/train/EURASIAN MAGPIE 완료
# 114 번째  /content/dataset/train/CRESTED CARACARA 완료
# 115 번째  /content/dataset/train/BEARDED REEDLING 완료
# 116 번째  /content/dataset/train/NORTHERN FLICKER 완료
# 117 번째  /content/dataset/train/GLOSSY IBIS 완료
# 118 번째  /content/dataset/train/MOURNING DOVE 완료
# 119 번째  /content/dataset/train/CRESTED FIREBACK 완료
# 120 번째  /content/dataset/train/TURQUOISE MOTMOT 완료
# 121 번째  /content/dataset/train/ROCK DOVE 완료
# 122 번째  /content/dataset/train/MYNA 완료
# 123 번째  /content/dataset/train/CHARA DE COLLAR 완료
# 124 번째  /content/dataset/train/SCARLET TANAGER 완료
# 125 번째  /content/dataset/train/ANHINGA 완료
# 126 번째  /content/dataset/train/GILA WOODPECKER 완료
# 127 번째  /content/dataset/train/RAINBOW LORIKEET 완료
# 128 번째  /content/dataset/train/KING VULTURE 완료
# 129 번째  /content/dataset/train/ABBOTTS BOOBY 완료
# 130 번째  /content/dataset/train/GO AWAY BIRD 완료
# 131 번째  /content/dataset/train/COMMON STARLING 완료
# 132 번째  /content/dataset/train/HAWFINCH 완료
# 133 번째  /content/dataset/train/TRUMPTER SWAN 완료
# 134 번째  /content/dataset/train/OSPREY 완료
# 135 번째  /content/dataset/train/ALTAMIRA YELLOWTHROAT 완료
# 136 번째  /content/dataset/train/CAPE GLOSSY STARLING 완료
# 137 번째  /content/dataset/train/FLAMINGO 완료
# 138 번째  /content/dataset/train/PINK ROBIN 완료
# 139 번째  /content/dataset/train/MAGPIE GOOSE 완료
# 140 번째  /content/dataset/train/WHITE BROWED CRAKE 완료
# 141 번째  /content/dataset/train/BANANAQUIT 완료
# 142 번째  /content/dataset/train/SCARLET CROWNED FRUIT DOVE 완료
# 143 번째  /content/dataset/train/GRAY CATBIRD 완료
# 144 번째  /content/dataset/train/GROVED BILLED ANI 완료
# 145 번째  /content/dataset/train/AMETHYST WOODSTAR 완료
# 146 번째  /content/dataset/train/CRIMSON CHAT 완료
# 147 번째  /content/dataset/train/CERULEAN WARBLER 완료
# 148 번째  /content/dataset/train/AZURE TANAGER 완료
# 149 번째  /content/dataset/train/WALL CREAPER 완료
# 150 번째  /content/dataset/train/AMERICAN PIPIT 완료
# 151 번째  /content/dataset/train/BANDED BROADBILL 완료
# 152 번째  /content/dataset/train/EASTERN ROSELLA 완료
# 153 번째  /content/dataset/train/YELLOW BELLIED FLOWERPECKER 완료
# 154 번째  /content/dataset/train/BULWERS PHEASANT 완료
# 155 번째  /content/dataset/train/EASTERN GOLDEN WEAVER 완료
# 156 번째  /content/dataset/train/PURPLE SWAMPHEN 완료
# 157 번째  /content/dataset/train/BLACK & YELLOW  BROADBILL 완료
# 158 번째  /content/dataset/train/PEACOCK 완료
# 159 번째  /content/dataset/train/BLACK BAZA 완료
# 160 번째  /content/dataset/train/EARED PITA 완료
# 161 번째  /content/dataset/train/EUROPEAN TURTLE DOVE 완료
# 162 번째  /content/dataset/train/HORNED LARK 완료
# 163 번째  /content/dataset/train/ANDEAN LAPWING 완료
# 164 번째  /content/dataset/train/WHITE THROATED BEE EATER 완료
# 165 번째  /content/dataset/train/WHITE CHEEKED TURACO 완료
# 166 번째  /content/dataset/train/EASTERN BLUEBIRD 완료
# 167 번째  /content/dataset/train/SATYR TRAGOPAN 완료
# 168 번째  /content/dataset/train/BORNEAN LEAFBIRD 완료
# 169 번째  /content/dataset/train/IWI 완료
# 170 번째  /content/dataset/train/SHOEBILL 완료
# 171 번째  /content/dataset/train/BLACKBURNIAM WARBLER 완료
# 172 번째  /content/dataset/train/CALIFORNIA CONDOR 완료
# 173 번째  /content/dataset/train/HELMET VANGA 완료
# 174 번째  /content/dataset/train/BAND TAILED GUAN 완료
# 175 번째  /content/dataset/train/STEAMER DUCK 완료
# 176 번째  /content/dataset/train/TAIWAN MAGPIE 완료
# 177 번째  /content/dataset/train/RUFOUS KINGFISHER 완료
# 178 번째  /content/dataset/train/SPOTTED CATBIRD 완료
# 179 번째  /content/dataset/train/PARUS MAJOR 완료
# 180 번째  /content/dataset/train/GILDED FLICKER 완료
# 181 번째  /content/dataset/train/BALD IBIS 완료
# 182 번째  /content/dataset/train/GREEN MAGPIE 완료
# 183 번째  /content/dataset/train/YELLOW CACIQUE 완료
# 184 번째  /content/dataset/train/EMPEROR PENGUIN 완료
# 185 번째  /content/dataset/train/NORTHERN FULMAR 완료
# 186 번째  /content/dataset/train/MALACHITE KINGFISHER 완료
# 187 번째  /content/dataset/train/RED TAILED THRUSH 완료
# 188 번째  /content/dataset/train/IVORY GULL 완료
# 189 번째  /content/dataset/train/HOODED MERGANSER 완료
# 190 번째  /content/dataset/train/GREEN BROADBILL 완료
# 191 번째  /content/dataset/train/NORTHERN GOSHAWK 완료
# 192 번째  /content/dataset/train/CHINESE BAMBOO PARTRIDGE 완료
# 193 번째  /content/dataset/train/BLACK FRANCOLIN 완료
# 194 번째  /content/dataset/train/BLACK-CAPPED CHICKADEE 완료
# 195 번째  /content/dataset/train/AZURE TIT 완료
# 196 번째  /content/dataset/train/MASKED LAPWING 완료
# 197 번째  /content/dataset/train/EASTERN TOWEE 완료
# 198 번째  /content/dataset/train/TOUCHAN 완료
# 199 번째  /content/dataset/train/HOUSE FINCH 완료
# 200 번째  /content/dataset/train/LONG-EARED OWL 완료
# 201 번째  /content/dataset/train/BEARDED BARBET 완료
# 202 번째  /content/dataset/train/ASHY THRUSHBIRD 완료
# 203 번째  /content/dataset/train/BROWN CREPPER 완료
# 204 번째  /content/dataset/train/BIRD OF PARADISE 완료
# 205 번째  /content/dataset/train/CINNAMON TEAL 완료
# 206 번째  /content/dataset/train/RED FACED WARBLER 완료
# 207 번째  /content/dataset/train/REGENT BOWERBIRD 완료
# 208 번째  /content/dataset/train/MALEO 완료
# 209 번째  /content/dataset/train/CASPIAN TERN 완료
# 210 번째  /content/dataset/train/BANDED STILT 완료
# 211 번째  /content/dataset/train/GREAT JACAMAR 완료
# 212 번째  /content/dataset/train/APAPANE 완료
# 213 번째  /content/dataset/train/WATTLED LAPWING 완료
# 214 번째  /content/dataset/train/ANTILLEAN EUPHONIA 완료
# 215 번째  /content/dataset/train/BEARDED BELLBIRD 완료
# 216 번째  /content/dataset/train/GREAT GRAY OWL 완료
# 217 번째  /content/dataset/train/FIRE TAILLED MYZORNIS 완료
# 218 번째  /content/dataset/train/BLACK-NECKED GREBE 완료
# 219 번째  /content/dataset/train/CHINESE POND HERON 완료
# 220 번째  /content/dataset/train/OKINAWA RAIL 완료
# 221 번째  /content/dataset/train/NORTHERN GANNET 완료
# 222 번째  /content/dataset/train/WHITE TAILED TROPIC 완료
# 223 번째  /content/dataset/train/PUFFIN 완료
# 224 번째  /content/dataset/train/HARPY EAGLE 완료
# 225 번째  /content/dataset/train/COPPERY TAILED COUCAL 완료
# 226 번째  /content/dataset/train/COMMON GRACKLE 완료
# 227 번째  /content/dataset/train/TIT MOUSE 완료
# 228 번째  /content/dataset/train/TOWNSENDS WARBLER 완료
# 229 번째  /content/dataset/train/VICTORIA CROWNED PIGEON 완료
# 230 번째  /content/dataset/train/ANTBIRD 완료
# 231 번째  /content/dataset/train/CHUKAR PARTRIDGE 완료
# 232 번째  /content/dataset/train/FRIGATE 완료
# 233 번째  /content/dataset/train/SORA 완료
# 234 번째  /content/dataset/train/KAGU 완료
# 235 번째  /content/dataset/train/BAR-TAILED GODWIT 완료
# 236 번째  /content/dataset/train/D-ARNAUDS BARBET 완료
# 237 번째  /content/dataset/train/ALBATROSS 완료
# 238 번째  /content/dataset/train/QUETZAL 완료
# 239 번째  /content/dataset/train/EURASIAN GOLDEN ORIOLE 완료
# 240 번째  /content/dataset/train/PURPLE FINCH 완료
# 241 번째  /content/dataset/train/EUROPEAN GOLDFINCH 완료
# 242 번째  /content/dataset/train/ROYAL FLYCATCHER 완료
# 243 번째  /content/dataset/train/HYACINTH MACAW 완료
# 244 번째  /content/dataset/train/SANDHILL CRANE 완료
# 245 번째  /content/dataset/train/MIKADO  PHEASANT 완료
# 246 번째  /content/dataset/train/HAMMERKOP 완료
# 247 번째  /content/dataset/train/ANIANIAU 완료
# 248 번째  /content/dataset/train/RED NAPED TROGON 완료
# 249 번째  /content/dataset/train/RED TAILED HAWK 완료
# 250 번째  /content/dataset/train/RED BEARDED BEE EATER 완료
# 251 번째  /content/dataset/train/IBERIAN MAGPIE 완료
# 252 번째  /content/dataset/train/BLACK THROATED WARBLER 완료
# 253 번째  /content/dataset/train/ROUGH LEG BUZZARD 완료
# 254 번째  /content/dataset/train/RING-NECKED PHEASANT 완료
# 255 번째  /content/dataset/train/WATTLED CURASSOW 완료
# 256 번째  /content/dataset/train/TAILORBIRD 완료
# 257 번째  /content/dataset/train/DOUBLE BARRED FINCH 완료
# 258 번째  /content/dataset/train/PARADISE TANAGER 완료
# 259 번째  /content/dataset/train/CHATTERING LORY 완료
# 260 번째  /content/dataset/train/CHIPPING SPARROW 완료
# 261 번째  /content/dataset/train/GOLDEN PHEASANT 완료
# 262 번째  /content/dataset/train/GREAT KISKADEE 완료
# 263 번째  /content/dataset/train/MALAGASY WHITE EYE 완료
# 264 번째  /content/dataset/train/RED WINGED BLACKBIRD 완료
# 265 번째  /content/dataset/train/CASSOWARY 완료
# 266 번째  /content/dataset/train/PURPLE MARTIN 완료
# 267 번째  /content/dataset/train/GUINEA TURACO 완료
# 268 번째  /content/dataset/train/SPLENDID WREN 완료
# 269 번째  /content/dataset/train/BRANDT CORMARANT 완료
# 270 번째  /content/dataset/train/RED FACED CORMORANT 완료
# 271 번째  /content/dataset/train/OYSTER CATCHER 완료
# 272 번째  /content/dataset/train/BORNEAN BRISTLEHEAD 완료
# 273 번째  /content/dataset/train/AVADAVAT 완료
# 274 번째  /content/dataset/train/CRAB PLOVER 완료
# 275 번째  /content/dataset/train/PATAGONIAN SIERRA FINCH 완료
# 276 번째  /content/dataset/train/BLACK VULTURE 완료
# 277 번째  /content/dataset/train/CUBAN TROGON 완료
# 278 번째  /content/dataset/train/RED HEADED DUCK 완료
# 279 번째  /content/dataset/train/EMU 완료
# 280 번째  /content/dataset/train/RED HEADED WOODPECKER 완료
# 281 번째  /content/dataset/train/GREAT POTOO 완료
# 282 번째  /content/dataset/train/AFRICAN OYSTER CATCHER 완료
# 283 번째  /content/dataset/train/HIMALAYAN MONAL 완료
# 284 번째  /content/dataset/train/JACK SNIPE 완료
# 285 번째  /content/dataset/train/GRAY PARTRIDGE 완료
# 286 번째  /content/dataset/train/AFRICAN FIREFINCH 완료
# 287 번째  /content/dataset/train/GOLDEN PIPIT 완료
# 288 번째  /content/dataset/train/SPOONBILL 완료
# 289 번째  /content/dataset/train/AFRICAN EMERALD CUCKOO 완료
# 290 번째  /content/dataset/train/CINNAMON FLYCATCHER 완료
# 291 번째  /content/dataset/train/GREEN JAY 완료
# 292 번째  /content/dataset/train/SAND MARTIN 완료
# 293 번째  /content/dataset/train/TREE SWALLOW 완료
# 294 번째  /content/dataset/train/RED BROWED FINCH 완료
# 295 번째  /content/dataset/train/BLONDE CRESTED WOODPECKER 완료
# 296 번째  /content/dataset/train/IMPERIAL SHAQ 완료
# 297 번째  /content/dataset/train/DOWNY WOODPECKER 완료
# 298 번째  /content/dataset/train/BLUE THROATED TOUCANET 완료
# 299 번째  /content/dataset/train/GOLDEN EAGLE 완료
# 300 번째  /content/dataset/train/JANDAYA PARAKEET 완료
# 301 번째  /content/dataset/train/BLACK THROATED BUSHTIT 완료
# 302 번째  /content/dataset/train/NICOBAR PIGEON 완료
# 303 번째  /content/dataset/train/CROWNED PIGEON 완료
# 304 번째  /content/dataset/train/CRANE HAWK 완료
# 305 번째  /content/dataset/train/GREY PLOVER 완료
# 306 번째  /content/dataset/train/ROADRUNNER 완료
# 307 번째  /content/dataset/train/GOLDEN CHEEKED WARBLER 완료
# 308 번째  /content/dataset/train/ALPINE CHOUGH 완료
# 309 번째  /content/dataset/train/CANARY 완료
# 310 번째  /content/dataset/train/OSTRICH 완료
# 311 번째  /content/dataset/train/MALABAR HORNBILL 완료
# 312 번째  /content/dataset/train/GYRFALCON 완료
# 313 번째  /content/dataset/train/SNOWY OWL 완료
# 314 번째  /content/dataset/train/DEMOISELLE CRANE 완료
# 315 번째  /content/dataset/train/BLACK-THROATED SPARROW 완료
# 316 번째  /content/dataset/train/DOUBLE EYED FIG PARROT 완료
# 317 번째  /content/dataset/train/PARAKETT  AKULET 완료
# 318 번째  /content/dataset/train/VERMILION FLYCATHER 완료
# 319 번째  /content/dataset/train/HIMALAYAN BLUETAIL 완료
# 320 번째  /content/dataset/train/CAPE ROCK THRUSH 완료
# 321 번째  /content/dataset/train/CALIFORNIA QUAIL 완료
# 322 번째  /content/dataset/train/CAPE LONGCLAW 완료
# 323 번째  /content/dataset/train/SUPERB STARLING 완료
# 324 번째  /content/dataset/train/CHESTNET BELLIED EUPHONIA 완료
# 325 번째  /content/dataset/train/STORK BILLED KINGFISHER 완료
# 326 번째  /content/dataset/train/DOUBLE BRESTED CORMARANT 완료
# 327 번째  /content/dataset/train/WILD TURKEY 완료
# 328 번째  /content/dataset/train/SMITHS LONGSPUR 완료
# 329 번째  /content/dataset/train/VARIED THRUSH 완료
# 330 번째  /content/dataset/train/TAKAHE 완료
# 331 번째  /content/dataset/train/AFRICAN CROWNED CRANE 완료
# 332 번째  /content/dataset/train/STRIPPED SWALLOW 완료
# 333 번째  /content/dataset/train/IBISBILL 완료
# 334 번째  /content/dataset/train/RED HONEY CREEPER 완료
# 335 번째  /content/dataset/train/GREATOR SAGE GROUSE 완료
# 336 번째  /content/dataset/train/FAIRY BLUEBIRD 완료
# 337 번째  /content/dataset/train/EMERALD TANAGER 완료
# 338 번째  /content/dataset/train/TROPICAL KINGBIRD 완료
# 339 번째  /content/dataset/train/ELLIOTS  PHEASANT 완료
# 340 번째  /content/dataset/train/PYGMY KINGFISHER 완료
# 341 번째  /content/dataset/train/PELICAN 완료
# 342 번째  /content/dataset/train/NORTHERN SHOVELER 완료
# 343 번째  /content/dataset/train/ARARIPE MANAKIN 완료
# 344 번째  /content/dataset/train/SPOON BILED SANDPIPER 완료
# 345 번째  /content/dataset/train/STRIPED OWL 완료
# 346 번째  /content/dataset/train/COMMON LOON 완료
# 347 번째  /content/dataset/train/BARN SWALLOW 완료
# 348 번째  /content/dataset/train/STRIPPED MANAKIN 완료
# 349 번째  /content/dataset/train/RUDY KINGFISHER 완료
# 350 번째  /content/dataset/train/GUINEAFOWL 완료
# 351 번째  /content/dataset/train/LILAC ROLLER 완료
# 352 번째  /content/dataset/train/JAPANESE ROBIN 완료
# 353 번째  /content/dataset/train/BOBOLINK 완료
# 354 번째  /content/dataset/train/SCARLET MACAW 완료
# 355 번째  /content/dataset/train/JABIRU 완료
# 356 번째  /content/dataset/train/BARN OWL 완료
# 357 번째  /content/dataset/train/COLLARED ARACARI 완료
# 358 번째  /content/dataset/train/ROBIN 완료
# 359 번째  /content/dataset/train/INDIGO BUNTING 완료
# 360 번째  /content/dataset/train/BLACK SKIMMER 완료
# 361 번째  /content/dataset/train/CAPE MAY WARBLER 완료
# 362 번째  /content/dataset/train/AMERICAN AVOCET 완료
# 363 번째  /content/dataset/train/APOSTLEBIRD 완료
# 364 번째  /content/dataset/train/HOOPOES 완료
# 365 번째  /content/dataset/train/BALTIMORE ORIOLE 완료
# 366 번째  /content/dataset/train/NORTHERN MOCKINGBIRD 완료
# 367 번째  /content/dataset/train/ALBERTS TOWHEE 완료
# 368 번째  /content/dataset/train/UMBRELLA BIRD 완료
# 369 번째  /content/dataset/train/DARK EYED JUNCO 완료
# 370 번째  /content/dataset/train/AMERICAN COOT 완료
# 371 번째  /content/dataset/train/LAZULI BUNTING 완료
# 372 번째  /content/dataset/train/CRESTED COUA 완료
# 373 번째  /content/dataset/train/POMARINE JAEGER 완료
# 374 번째  /content/dataset/train/OVENBIRD 완료
# 375 번째  /content/dataset/train/HEPATIC TANAGER 완료
# 376 번째  /content/dataset/train/BUSH TURKEY 완료
# 377 번째  /content/dataset/train/FLAME BOWERBIRD 완료
# 378 번째  /content/dataset/train/CACTUS WREN 완료
# 379 번째  /content/dataset/train/NOISY FRIARBIRD 완료
# 380 번째  /content/dataset/train/CARMINE BEE-EATER 완료
# 381 번째  /content/dataset/train/PHILIPPINE EAGLE 완료
# 382 번째  /content/dataset/train/COMMON POORWILL 완료
# 383 번째  /content/dataset/train/BANDED PITA 완료
# 384 번째  /content/dataset/train/PURPLE GALLINULE 완료
# 385 번째  /content/dataset/train/CREAM COLORED WOODPECKER 완료
# 386 번째  /content/dataset/train/CURL CRESTED ARACURI 완료
# 387 번째  /content/dataset/train/HAWAIIAN GOOSE 완료
# 388 번째  /content/dataset/train/YELLOW HEADED BLACKBIRD 완료
# 389 번째  /content/dataset/train/BAIKAL TEAL 완료
# 390 번째  /content/dataset/train/CRESTED OROPENDOLA 완료
# 391 번째  /content/dataset/train/MARABOU STORK 완료
# 392 번째  /content/dataset/train/RED BELLIED PITTA 완료
# 393 번째  /content/dataset/train/BAY-BREASTED WARBLER 완료
# 394 번째  /content/dataset/train/NORTHERN JACANA 완료
# 395 번째  /content/dataset/train/COCK OF THE  ROCK 완료
# 396 번째  /content/dataset/train/RED WISKERED BULBUL 완료
# 397 번째  /content/dataset/train/BROWN THRASHER 완료
# 398 번째  /content/dataset/train/AMERICAN GOLDFINCH 완료
# 399 번째  /content/dataset/train/CHUCAO TAPACULO 완료
# 400 번째  /content/dataset/train/CINNAMON ATTILA 완료

# %%
# data augmentation 2
num_augmented_images = 100

file_path = '/content/dataset/train/'
folder_names = os.listdir(file_path)
total_origin_folder_num = len(folder_names)
print(total_origin_folder_num) # 폴더 400개가 맞는지 확인

for k in range(total_origin_folder_num):
  folder_name = file_path + folder_names[k]
  file_names = os.listdir(folder_name)
  total_origin_image_num = len(file_names)
  augment_cnt = 1

  for i in range(num_augmented_images):
      change_picture_index = random.randrange(1, total_origin_image_num-1)

      file_name = file_names[change_picture_index]
    
      origin_image_path = folder_name + '/' + file_name
      image = Image.open(origin_image_path)

      transform = transforms.Compose([transforms.RandomRotation(45),
                                      transforms.RandomPerspective(distortion_scale=0.2, p=1)])

      transform_image = transform(image)
      transform_image.save(folder_name + '/transform_x2_' + str(augment_cnt) + '.jpg')

      augment_cnt += 1

  print(k+1, '번째 ', folder_name, '완료')
# Out:
# 400
# 1 번째  /content/dataset/train/INDIAN BUSTARD 완료
# 2 번째  /content/dataset/train/CLARKS NUTCRACKER 완료
# 3 번째  /content/dataset/train/SWINHOES PHEASANT 완료
# 4 번째  /content/dataset/train/RUBY THROATED HUMMINGBIRD 완료
# 5 번째  /content/dataset/train/CALIFORNIA GULL 완료
# 6 번째  /content/dataset/train/COCKATOO 완료
# 7 번째  /content/dataset/train/GOLD WING WARBLER 완료
# 8 번째  /content/dataset/train/COMMON FIRECREST 완료
# 9 번째  /content/dataset/train/ELEGANT TROGON 완료
# 10 번째  /content/dataset/train/NORTHERN CARDINAL 완료
# 11 번째  /content/dataset/train/BLACK COCKATO 완료
# 12 번째  /content/dataset/train/COMMON IORA 완료
# 13 번째  /content/dataset/train/ROSY FACED LOVEBIRD 완료
# 14 번째  /content/dataset/train/BLACK TAIL CRAKE 완료
# 15 번째  /content/dataset/train/GAMBELS QUAIL 완료
# 16 번째  /content/dataset/train/NORTHERN PARULA 완료
# 17 번째  /content/dataset/train/CRESTED AUKLET 완료
# 18 번째  /content/dataset/train/MALLARD DUCK 완료
# 19 번째  /content/dataset/train/INDIAN ROLLER 완료
# 20 번째  /content/dataset/train/HOUSE SPARROW 완료
# 21 번째  /content/dataset/train/RUFUOS MOTMOT 완료
# 22 번째  /content/dataset/train/HORNED GUAN 완료
# 23 번째  /content/dataset/train/BARROWS GOLDENEYE 완료
# 24 번째  /content/dataset/train/EVENING GROSBEAK 완료
# 25 번째  /content/dataset/train/AMERICAN KESTREL 완료
# 26 번째  /content/dataset/train/CRESTED NUTHATCH 완료
# 27 번째  /content/dataset/train/RED FODY 완료
# 28 번째  /content/dataset/train/FIORDLAND PENGUIN 완료
# 29 번째  /content/dataset/train/HORNBILL 완료
# 30 번째  /content/dataset/train/INLAND DOTTEREL 완료
# 31 번째  /content/dataset/train/GOULDIAN FINCH 완료
# 32 번째  /content/dataset/train/LITTLE AUK 완료
# 33 번째  /content/dataset/train/LESSER ADJUTANT 완료
# 34 번째  /content/dataset/train/DUSKY LORY 완료
# 35 번째  /content/dataset/train/INDIAN PITTA 완료
# 36 번째  /content/dataset/train/MANGROVE CUCKOO 완료
# 37 번째  /content/dataset/train/HARLEQUIN QUAIL 완료
# 38 번째  /content/dataset/train/NORTHERN RED BISHOP 완료
# 39 번째  /content/dataset/train/JAVA SPARROW 완료
# 40 번째  /content/dataset/train/GRAY KINGBIRD 완료
# 41 번째  /content/dataset/train/GOLDEN CHLOROPHONIA 완료
# 42 번째  /content/dataset/train/BLUE COAU 완료
# 43 번째  /content/dataset/train/ANDEAN SISKIN 완료
# 44 번째  /content/dataset/train/BORNEAN PHEASANT 완료
# 45 번째  /content/dataset/train/AMERICAN BITTERN 완료
# 46 번째  /content/dataset/train/RAZORBILL 완료
# 47 번째  /content/dataset/train/ENGGANO MYNA 완료
# 48 번째  /content/dataset/train/KOOKABURRA 완료
# 49 번째  /content/dataset/train/ALEXANDRINE PARAKEET 완료
# 50 번째  /content/dataset/train/GANG GANG COCKATOO 완료
# 51 번째  /content/dataset/train/SRI LANKA BLUE MAGPIE 완료
# 52 번째  /content/dataset/train/HORNED SUNGEM 완료
# 53 번째  /content/dataset/train/MASKED BOOBY 완료
# 54 번째  /content/dataset/train/TASMANIAN HEN 완료
# 55 번째  /content/dataset/train/ABBOTTS BABBLER 완료
# 56 번째  /content/dataset/train/VULTURINE GUINEAFOWL 완료
# 57 번째  /content/dataset/train/SCARLET IBIS 완료
# 58 번째  /content/dataset/train/WILSONS BIRD OF PARADISE 완료
# 59 번째  /content/dataset/train/VENEZUELIAN TROUPIAL 완료
# 60 번째  /content/dataset/train/BLUE HERON 완료
# 61 번째  /content/dataset/train/ABYSSINIAN GROUND HORNBILL 완료
# 62 번째  /content/dataset/train/CROW 완료
# 63 번째  /content/dataset/train/VIOLET GREEN SWALLOW 완료
# 64 번째  /content/dataset/train/BLACK SWAN 완료
# 65 번째  /content/dataset/train/PAINTED BUNTING 완료
# 66 번째  /content/dataset/train/ORIENTAL BAY OWL 완료
# 67 번째  /content/dataset/train/CRIMSON SUNBIRD 완료
# 68 번째  /content/dataset/train/GURNEYS PITTA 완료
# 69 번째  /content/dataset/train/BELTED KINGFISHER 완료
# 70 번째  /content/dataset/train/MANDRIN DUCK 완료
# 71 번째  /content/dataset/train/WHIMBREL 완료
# 72 번째  /content/dataset/train/SAMATRAN THRUSH 완료
# 73 번째  /content/dataset/train/WHITE NECKED RAVEN 완료
# 74 번째  /content/dataset/train/PALILA 완료
# 75 번째  /content/dataset/train/HARLEQUIN DUCK 완료
# 76 번째  /content/dataset/train/CUBAN TODY 완료
# 77 번째  /content/dataset/train/BALI STARLING 완료
# 78 번째  /content/dataset/train/CRESTED KINGFISHER 완료
# 79 번째  /content/dataset/train/TEAL DUCK 완료
# 80 번째  /content/dataset/train/OCELLATED TURKEY 완료
# 81 번째  /content/dataset/train/BLUE GROUSE 완료
# 82 번째  /content/dataset/train/BROWN NOODY 완료
# 83 번째  /content/dataset/train/FAIRY TERN 완료
# 84 번째  /content/dataset/train/ASIAN CRESTED IBIS 완료
# 85 번째  /content/dataset/train/AMERICAN REDSTART 완료
# 86 번째  /content/dataset/train/EASTERN MEADOWLARK 완료
# 87 번째  /content/dataset/train/SPANGLED COTINGA 완료
# 88 번째  /content/dataset/train/SNOWY EGRET 완료
# 89 번째  /content/dataset/train/INCA TERN 완료
# 90 번째  /content/dataset/train/AZURE JAY 완료
# 91 번째  /content/dataset/train/KIWI 완료
# 92 번째  /content/dataset/train/KILLDEAR 완료
# 93 번째  /content/dataset/train/CRESTED SHRIKETIT 완료
# 94 번째  /content/dataset/train/STRAWBERRY FINCH 완료
# 95 번째  /content/dataset/train/BALD EAGLE 완료
# 96 번째  /content/dataset/train/CAPUCHINBIRD 완료
# 97 번째  /content/dataset/train/VIOLET TURACO 완료
# 98 번째  /content/dataset/train/CEDAR WAXWING 완료
# 99 번째  /content/dataset/train/WOOD DUCK 완료
# 100 번째  /content/dataset/train/KAKAPO 완료
# 101 번째  /content/dataset/train/BARRED PUFFBIRD 완료
# 102 번째  /content/dataset/train/FLAME TANAGER 완료
# 103 번째  /content/dataset/train/ANDEAN GOOSE 완료
# 104 번째  /content/dataset/train/ORANGE BRESTED BUNTING 완료
# 105 번째  /content/dataset/train/HOATZIN 완료
# 106 번째  /content/dataset/train/TURKEY VULTURE 완료
# 107 번째  /content/dataset/train/PEREGRINE FALCON 완료
# 108 번째  /content/dataset/train/CAPPED HERON 완료
# 109 번째  /content/dataset/train/LARK BUNTING 완료
# 110 번째  /content/dataset/train/SHORT BILLED DOWITCHER 완료
# 111 번째  /content/dataset/train/ANNAS HUMMINGBIRD 완료
# 112 번째  /content/dataset/train/COMMON HOUSE MARTIN 완료
# 113 번째  /content/dataset/train/EURASIAN MAGPIE 완료
# 114 번째  /content/dataset/train/CRESTED CARACARA 완료
# 115 번째  /content/dataset/train/BEARDED REEDLING 완료
# 116 번째  /content/dataset/train/NORTHERN FLICKER 완료
# 117 번째  /content/dataset/train/GLOSSY IBIS 완료
# 118 번째  /content/dataset/train/MOURNING DOVE 완료
# 119 번째  /content/dataset/train/CRESTED FIREBACK 완료
# 120 번째  /content/dataset/train/TURQUOISE MOTMOT 완료
# 121 번째  /content/dataset/train/ROCK DOVE 완료
# 122 번째  /content/dataset/train/MYNA 완료
# 123 번째  /content/dataset/train/CHARA DE COLLAR 완료
# 124 번째  /content/dataset/train/SCARLET TANAGER 완료
# 125 번째  /content/dataset/train/ANHINGA 완료
# 126 번째  /content/dataset/train/GILA WOODPECKER 완료
# 127 번째  /content/dataset/train/RAINBOW LORIKEET 완료
# 128 번째  /content/dataset/train/KING VULTURE 완료
# 129 번째  /content/dataset/train/ABBOTTS BOOBY 완료
# 130 번째  /content/dataset/train/GO AWAY BIRD 완료
# 131 번째  /content/dataset/train/COMMON STARLING 완료
# 132 번째  /content/dataset/train/HAWFINCH 완료
# 133 번째  /content/dataset/train/TRUMPTER SWAN 완료
# 134 번째  /content/dataset/train/OSPREY 완료
# 135 번째  /content/dataset/train/ALTAMIRA YELLOWTHROAT 완료
# 136 번째  /content/dataset/train/CAPE GLOSSY STARLING 완료
# 137 번째  /content/dataset/train/FLAMINGO 완료
# 138 번째  /content/dataset/train/PINK ROBIN 완료
# 139 번째  /content/dataset/train/MAGPIE GOOSE 완료
# 140 번째  /content/dataset/train/WHITE BROWED CRAKE 완료
# 141 번째  /content/dataset/train/BANANAQUIT 완료
# 142 번째  /content/dataset/train/SCARLET CROWNED FRUIT DOVE 완료
# 143 번째  /content/dataset/train/GRAY CATBIRD 완료
# 144 번째  /content/dataset/train/GROVED BILLED ANI 완료
# 145 번째  /content/dataset/train/AMETHYST WOODSTAR 완료
# 146 번째  /content/dataset/train/CRIMSON CHAT 완료
# 147 번째  /content/dataset/train/CERULEAN WARBLER 완료
# 148 번째  /content/dataset/train/AZURE TANAGER 완료
# 149 번째  /content/dataset/train/WALL CREAPER 완료
# 150 번째  /content/dataset/train/AMERICAN PIPIT 완료
# 151 번째  /content/dataset/train/BANDED BROADBILL 완료
# 152 번째  /content/dataset/train/EASTERN ROSELLA 완료
# 153 번째  /content/dataset/train/YELLOW BELLIED FLOWERPECKER 완료
# 154 번째  /content/dataset/train/BULWERS PHEASANT 완료
# 155 번째  /content/dataset/train/EASTERN GOLDEN WEAVER 완료
# 156 번째  /content/dataset/train/PURPLE SWAMPHEN 완료
# 157 번째  /content/dataset/train/BLACK & YELLOW  BROADBILL 완료
# 158 번째  /content/dataset/train/PEACOCK 완료
# 159 번째  /content/dataset/train/BLACK BAZA 완료
# 160 번째  /content/dataset/train/EARED PITA 완료
# 161 번째  /content/dataset/train/EUROPEAN TURTLE DOVE 완료
# 162 번째  /content/dataset/train/HORNED LARK 완료
# 163 번째  /content/dataset/train/ANDEAN LAPWING 완료
# 164 번째  /content/dataset/train/WHITE THROATED BEE EATER 완료
# 165 번째  /content/dataset/train/WHITE CHEEKED TURACO 완료
# 166 번째  /content/dataset/train/EASTERN BLUEBIRD 완료
# 167 번째  /content/dataset/train/SATYR TRAGOPAN 완료
# 168 번째  /content/dataset/train/BORNEAN LEAFBIRD 완료
# 169 번째  /content/dataset/train/IWI 완료
# 170 번째  /content/dataset/train/SHOEBILL 완료
# 171 번째  /content/dataset/train/BLACKBURNIAM WARBLER 완료
# 172 번째  /content/dataset/train/CALIFORNIA CONDOR 완료
# 173 번째  /content/dataset/train/HELMET VANGA 완료
# 174 번째  /content/dataset/train/BAND TAILED GUAN 완료
# 175 번째  /content/dataset/train/STEAMER DUCK 완료
# 176 번째  /content/dataset/train/TAIWAN MAGPIE 완료
# 177 번째  /content/dataset/train/RUFOUS KINGFISHER 완료
# 178 번째  /content/dataset/train/SPOTTED CATBIRD 완료
# 179 번째  /content/dataset/train/PARUS MAJOR 완료
# 180 번째  /content/dataset/train/GILDED FLICKER 완료
# 181 번째  /content/dataset/train/BALD IBIS 완료
# 182 번째  /content/dataset/train/GREEN MAGPIE 완료
# 183 번째  /content/dataset/train/YELLOW CACIQUE 완료
# 184 번째  /content/dataset/train/EMPEROR PENGUIN 완료
# 185 번째  /content/dataset/train/NORTHERN FULMAR 완료
# 186 번째  /content/dataset/train/MALACHITE KINGFISHER 완료
# 187 번째  /content/dataset/train/RED TAILED THRUSH 완료
# 188 번째  /content/dataset/train/IVORY GULL 완료
# 189 번째  /content/dataset/train/HOODED MERGANSER 완료
# 190 번째  /content/dataset/train/GREEN BROADBILL 완료
# 191 번째  /content/dataset/train/NORTHERN GOSHAWK 완료
# 192 번째  /content/dataset/train/CHINESE BAMBOO PARTRIDGE 완료
# 193 번째  /content/dataset/train/BLACK FRANCOLIN 완료
# 194 번째  /content/dataset/train/BLACK-CAPPED CHICKADEE 완료
# 195 번째  /content/dataset/train/AZURE TIT 완료
# 196 번째  /content/dataset/train/MASKED LAPWING 완료
# 197 번째  /content/dataset/train/EASTERN TOWEE 완료
# 198 번째  /content/dataset/train/TOUCHAN 완료
# 199 번째  /content/dataset/train/HOUSE FINCH 완료
# 200 번째  /content/dataset/train/LONG-EARED OWL 완료
# 201 번째  /content/dataset/train/BEARDED BARBET 완료
# 202 번째  /content/dataset/train/ASHY THRUSHBIRD 완료
# 203 번째  /content/dataset/train/BROWN CREPPER 완료
# 204 번째  /content/dataset/train/BIRD OF PARADISE 완료
# 205 번째  /content/dataset/train/CINNAMON TEAL 완료
# 206 번째  /content/dataset/train/RED FACED WARBLER 완료
# 207 번째  /content/dataset/train/REGENT BOWERBIRD 완료
# 208 번째  /content/dataset/train/MALEO 완료
# 209 번째  /content/dataset/train/CASPIAN TERN 완료
# 210 번째  /content/dataset/train/BANDED STILT 완료
# 211 번째  /content/dataset/train/GREAT JACAMAR 완료
# 212 번째  /content/dataset/train/APAPANE 완료
# 213 번째  /content/dataset/train/WATTLED LAPWING 완료
# 214 번째  /content/dataset/train/ANTILLEAN EUPHONIA 완료
# 215 번째  /content/dataset/train/BEARDED BELLBIRD 완료
# 216 번째  /content/dataset/train/GREAT GRAY OWL 완료
# 217 번째  /content/dataset/train/FIRE TAILLED MYZORNIS 완료
# 218 번째  /content/dataset/train/BLACK-NECKED GREBE 완료
# 219 번째  /content/dataset/train/CHINESE POND HERON 완료
# 220 번째  /content/dataset/train/OKINAWA RAIL 완료
# 221 번째  /content/dataset/train/NORTHERN GANNET 완료
# 222 번째  /content/dataset/train/WHITE TAILED TROPIC 완료
# 223 번째  /content/dataset/train/PUFFIN 완료
# 224 번째  /content/dataset/train/HARPY EAGLE 완료
# 225 번째  /content/dataset/train/COPPERY TAILED COUCAL 완료
# 226 번째  /content/dataset/train/COMMON GRACKLE 완료
# 227 번째  /content/dataset/train/TIT MOUSE 완료
# 228 번째  /content/dataset/train/TOWNSENDS WARBLER 완료
# 229 번째  /content/dataset/train/VICTORIA CROWNED PIGEON 완료
# 230 번째  /content/dataset/train/ANTBIRD 완료
# 231 번째  /content/dataset/train/CHUKAR PARTRIDGE 완료
# 232 번째  /content/dataset/train/FRIGATE 완료
# 233 번째  /content/dataset/train/SORA 완료
# 234 번째  /content/dataset/train/KAGU 완료
# 235 번째  /content/dataset/train/BAR-TAILED GODWIT 완료
# 236 번째  /content/dataset/train/D-ARNAUDS BARBET 완료
# 237 번째  /content/dataset/train/ALBATROSS 완료
# 238 번째  /content/dataset/train/QUETZAL 완료
# 239 번째  /content/dataset/train/EURASIAN GOLDEN ORIOLE 완료
# 240 번째  /content/dataset/train/PURPLE FINCH 완료
# 241 번째  /content/dataset/train/EUROPEAN GOLDFINCH 완료
# 242 번째  /content/dataset/train/ROYAL FLYCATCHER 완료
# 243 번째  /content/dataset/train/HYACINTH MACAW 완료
# 244 번째  /content/dataset/train/SANDHILL CRANE 완료
# 245 번째  /content/dataset/train/MIKADO  PHEASANT 완료
# 246 번째  /content/dataset/train/HAMMERKOP 완료
# 247 번째  /content/dataset/train/ANIANIAU 완료
# 248 번째  /content/dataset/train/RED NAPED TROGON 완료
# 249 번째  /content/dataset/train/RED TAILED HAWK 완료
# 250 번째  /content/dataset/train/RED BEARDED BEE EATER 완료
# 251 번째  /content/dataset/train/IBERIAN MAGPIE 완료
# 252 번째  /content/dataset/train/BLACK THROATED WARBLER 완료
# 253 번째  /content/dataset/train/ROUGH LEG BUZZARD 완료
# 254 번째  /content/dataset/train/RING-NECKED PHEASANT 완료
# 255 번째  /content/dataset/train/WATTLED CURASSOW 완료
# 256 번째  /content/dataset/train/TAILORBIRD 완료
# 257 번째  /content/dataset/train/DOUBLE BARRED FINCH 완료
# 258 번째  /content/dataset/train/PARADISE TANAGER 완료
# 259 번째  /content/dataset/train/CHATTERING LORY 완료
# 260 번째  /content/dataset/train/CHIPPING SPARROW 완료
# 261 번째  /content/dataset/train/GOLDEN PHEASANT 완료
# 262 번째  /content/dataset/train/GREAT KISKADEE 완료
# 263 번째  /content/dataset/train/MALAGASY WHITE EYE 완료
# 264 번째  /content/dataset/train/RED WINGED BLACKBIRD 완료
# 265 번째  /content/dataset/train/CASSOWARY 완료
# 266 번째  /content/dataset/train/PURPLE MARTIN 완료
# 267 번째  /content/dataset/train/GUINEA TURACO 완료
# 268 번째  /content/dataset/train/SPLENDID WREN 완료
# 269 번째  /content/dataset/train/BRANDT CORMARANT 완료
# 270 번째  /content/dataset/train/RED FACED CORMORANT 완료
# 271 번째  /content/dataset/train/OYSTER CATCHER 완료
# 272 번째  /content/dataset/train/BORNEAN BRISTLEHEAD 완료
# 273 번째  /content/dataset/train/AVADAVAT 완료
# 274 번째  /content/dataset/train/CRAB PLOVER 완료
# 275 번째  /content/dataset/train/PATAGONIAN SIERRA FINCH 완료
# 276 번째  /content/dataset/train/BLACK VULTURE 완료
# 277 번째  /content/dataset/train/CUBAN TROGON 완료
# 278 번째  /content/dataset/train/RED HEADED DUCK 완료
# 279 번째  /content/dataset/train/EMU 완료
# 280 번째  /content/dataset/train/RED HEADED WOODPECKER 완료
# 281 번째  /content/dataset/train/GREAT POTOO 완료
# 282 번째  /content/dataset/train/AFRICAN OYSTER CATCHER 완료
# 283 번째  /content/dataset/train/HIMALAYAN MONAL 완료
# 284 번째  /content/dataset/train/JACK SNIPE 완료
# 285 번째  /content/dataset/train/GRAY PARTRIDGE 완료
# 286 번째  /content/dataset/train/AFRICAN FIREFINCH 완료
# 287 번째  /content/dataset/train/GOLDEN PIPIT 완료
# 288 번째  /content/dataset/train/SPOONBILL 완료
# 289 번째  /content/dataset/train/AFRICAN EMERALD CUCKOO 완료
# 290 번째  /content/dataset/train/CINNAMON FLYCATCHER 완료
# 291 번째  /content/dataset/train/GREEN JAY 완료
# 292 번째  /content/dataset/train/SAND MARTIN 완료
# 293 번째  /content/dataset/train/TREE SWALLOW 완료
# 294 번째  /content/dataset/train/RED BROWED FINCH 완료
# 295 번째  /content/dataset/train/BLONDE CRESTED WOODPECKER 완료
# 296 번째  /content/dataset/train/IMPERIAL SHAQ 완료
# 297 번째  /content/dataset/train/DOWNY WOODPECKER 완료
# 298 번째  /content/dataset/train/BLUE THROATED TOUCANET 완료
# 299 번째  /content/dataset/train/GOLDEN EAGLE 완료
# 300 번째  /content/dataset/train/JANDAYA PARAKEET 완료
# 301 번째  /content/dataset/train/BLACK THROATED BUSHTIT 완료
# 302 번째  /content/dataset/train/NICOBAR PIGEON 완료
# 303 번째  /content/dataset/train/CROWNED PIGEON 완료
# 304 번째  /content/dataset/train/CRANE HAWK 완료
# 305 번째  /content/dataset/train/GREY PLOVER 완료
# 306 번째  /content/dataset/train/ROADRUNNER 완료
# 307 번째  /content/dataset/train/GOLDEN CHEEKED WARBLER 완료
# 308 번째  /content/dataset/train/ALPINE CHOUGH 완료
# 309 번째  /content/dataset/train/CANARY 완료
# 310 번째  /content/dataset/train/OSTRICH 완료
# 311 번째  /content/dataset/train/MALABAR HORNBILL 완료
# 312 번째  /content/dataset/train/GYRFALCON 완료
# 313 번째  /content/dataset/train/SNOWY OWL 완료
# 314 번째  /content/dataset/train/DEMOISELLE CRANE 완료
# 315 번째  /content/dataset/train/BLACK-THROATED SPARROW 완료
# 316 번째  /content/dataset/train/DOUBLE EYED FIG PARROT 완료
# 317 번째  /content/dataset/train/PARAKETT  AKULET 완료
# 318 번째  /content/dataset/train/VERMILION FLYCATHER 완료
# 319 번째  /content/dataset/train/HIMALAYAN BLUETAIL 완료
# 320 번째  /content/dataset/train/CAPE ROCK THRUSH 완료
# 321 번째  /content/dataset/train/CALIFORNIA QUAIL 완료
# 322 번째  /content/dataset/train/CAPE LONGCLAW 완료
# 323 번째  /content/dataset/train/SUPERB STARLING 완료
# 324 번째  /content/dataset/train/CHESTNET BELLIED EUPHONIA 완료
# 325 번째  /content/dataset/train/STORK BILLED KINGFISHER 완료
# 326 번째  /content/dataset/train/DOUBLE BRESTED CORMARANT 완료
# 327 번째  /content/dataset/train/WILD TURKEY 완료
# 328 번째  /content/dataset/train/SMITHS LONGSPUR 완료
# 329 번째  /content/dataset/train/VARIED THRUSH 완료
# 330 번째  /content/dataset/train/TAKAHE 완료
# 331 번째  /content/dataset/train/AFRICAN CROWNED CRANE 완료
# 332 번째  /content/dataset/train/STRIPPED SWALLOW 완료
# 333 번째  /content/dataset/train/IBISBILL 완료
# 334 번째  /content/dataset/train/RED HONEY CREEPER 완료
# 335 번째  /content/dataset/train/GREATOR SAGE GROUSE 완료
# 336 번째  /content/dataset/train/FAIRY BLUEBIRD 완료
# 337 번째  /content/dataset/train/EMERALD TANAGER 완료
# 338 번째  /content/dataset/train/TROPICAL KINGBIRD 완료
# 339 번째  /content/dataset/train/ELLIOTS  PHEASANT 완료
# 340 번째  /content/dataset/train/PYGMY KINGFISHER 완료
# 341 번째  /content/dataset/train/PELICAN 완료
# 342 번째  /content/dataset/train/NORTHERN SHOVELER 완료
# 343 번째  /content/dataset/train/ARARIPE MANAKIN 완료
# 344 번째  /content/dataset/train/SPOON BILED SANDPIPER 완료
# 345 번째  /content/dataset/train/STRIPED OWL 완료
# 346 번째  /content/dataset/train/COMMON LOON 완료
# 347 번째  /content/dataset/train/BARN SWALLOW 완료
# 348 번째  /content/dataset/train/STRIPPED MANAKIN 완료
# 349 번째  /content/dataset/train/RUDY KINGFISHER 완료
# 350 번째  /content/dataset/train/GUINEAFOWL 완료
# 351 번째  /content/dataset/train/LILAC ROLLER 완료
# 352 번째  /content/dataset/train/JAPANESE ROBIN 완료
# 353 번째  /content/dataset/train/BOBOLINK 완료
# 354 번째  /content/dataset/train/SCARLET MACAW 완료
# 355 번째  /content/dataset/train/JABIRU 완료
# 356 번째  /content/dataset/train/BARN OWL 완료
# 357 번째  /content/dataset/train/COLLARED ARACARI 완료
# 358 번째  /content/dataset/train/ROBIN 완료
# 359 번째  /content/dataset/train/INDIGO BUNTING 완료
# 360 번째  /content/dataset/train/BLACK SKIMMER 완료
# 361 번째  /content/dataset/train/CAPE MAY WARBLER 완료
# 362 번째  /content/dataset/train/AMERICAN AVOCET 완료
# 363 번째  /content/dataset/train/APOSTLEBIRD 완료
# 364 번째  /content/dataset/train/HOOPOES 완료
# 365 번째  /content/dataset/train/BALTIMORE ORIOLE 완료
# 366 번째  /content/dataset/train/NORTHERN MOCKINGBIRD 완료
# 367 번째  /content/dataset/train/ALBERTS TOWHEE 완료
# 368 번째  /content/dataset/train/UMBRELLA BIRD 완료
# 369 번째  /content/dataset/train/DARK EYED JUNCO 완료
# 370 번째  /content/dataset/train/AMERICAN COOT 완료
# 371 번째  /content/dataset/train/LAZULI BUNTING 완료
# 372 번째  /content/dataset/train/CRESTED COUA 완료
# 373 번째  /content/dataset/train/POMARINE JAEGER 완료
# 374 번째  /content/dataset/train/OVENBIRD 완료
# 375 번째  /content/dataset/train/HEPATIC TANAGER 완료
# 376 번째  /content/dataset/train/BUSH TURKEY 완료
# 377 번째  /content/dataset/train/FLAME BOWERBIRD 완료
# 378 번째  /content/dataset/train/CACTUS WREN 완료
# 379 번째  /content/dataset/train/NOISY FRIARBIRD 완료
# 380 번째  /content/dataset/train/CARMINE BEE-EATER 완료
# 381 번째  /content/dataset/train/PHILIPPINE EAGLE 완료
# 382 번째  /content/dataset/train/COMMON POORWILL 완료
# 383 번째  /content/dataset/train/BANDED PITA 완료
# 384 번째  /content/dataset/train/PURPLE GALLINULE 완료
# 385 번째  /content/dataset/train/CREAM COLORED WOODPECKER 완료
# 386 번째  /content/dataset/train/CURL CRESTED ARACURI 완료
# 387 번째  /content/dataset/train/HAWAIIAN GOOSE 완료
# 388 번째  /content/dataset/train/YELLOW HEADED BLACKBIRD 완료
# 389 번째  /content/dataset/train/BAIKAL TEAL 완료
# 390 번째  /content/dataset/train/CRESTED OROPENDOLA 완료
# 391 번째  /content/dataset/train/MARABOU STORK 완료
# 392 번째  /content/dataset/train/RED BELLIED PITTA 완료
# 393 번째  /content/dataset/train/BAY-BREASTED WARBLER 완료
# 394 번째  /content/dataset/train/NORTHERN JACANA 완료
# 395 번째  /content/dataset/train/COCK OF THE  ROCK 완료
# 396 번째  /content/dataset/train/RED WISKERED BULBUL 완료
# 397 번째  /content/dataset/train/BROWN THRASHER 완료
# 398 번째  /content/dataset/train/AMERICAN GOLDFINCH 완료
# 399 번째  /content/dataset/train/CHUCAO TAPACULO 완료
# 400 번째  /content/dataset/train/CINNAMON ATTILA 완료

# %%
# Knowing the data 
# data_dir = '/kaggle/input/100-bird-species/175/'
data_dir = '/content/dataset/train'

classes = []
img_per_class = []
# for folder in os.listdir(data_dir+'consolidated'):/
for folder in os.listdir(data_dir):    
    classes.append(folder)
    img_per_class.append(len(os.listdir(f'{data_dir}/{folder}')))
num_classes = len(classes)
df = pd.DataFrame({'Classes':classes, 'Examples':img_per_class})

print('총 데이터 갯수: ', df['Examples'].sum())
df
# Out:
# 총 데이터 갯수:  146388
#                        Classes  Examples
# 0               INDIAN BUSTARD       351
# 1            CLARKS NUTCRACKER       381
# 2            SWINHOES PHEASANT       437
# 3    RUBY THROATED HUMMINGBIRD       355
# 4              CALIFORNIA GULL       340
# ..                         ...       ...
# 395        RED WISKERED BULBUL       343
# 396             BROWN THRASHER       385
# 397         AMERICAN GOLDFINCH       353
# 398            CHUCAO TAPACULO       361
# 399            CINNAMON ATTILA       344
#
# [400 rows x 2 columns]

# %% [markdown]
# Train 시 로그를 보여주기위해 선언한 Class입니다.

# %%
class AverageMeter(object):
    r"""Computes and stores the average and current value
    """
    def __init__(self, name, fmt=':f'):
        self.name = name
        self.fmt = fmt
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def __str__(self):
        fmtstr = '{name} {val' + self.fmt + '} ({avg' + self.fmt + '})'
        return fmtstr.format(**self.__dict__)


class ProgressMeter(object):
    def __init__(self, num_batches, *meters, prefix=""):
        self.batch_fmtstr = self._get_batch_fmtstr(num_batches)
        self.meters = meters
        self.prefix = prefix

    def print(self, batch):
        entries = [self.prefix + self.batch_fmtstr.format(batch)]
        entries += [str(meter) for meter in self.meters]
        print('\t'.join(entries))

    def _get_batch_fmtstr(self, num_batches):
        num_digits = len(str(num_batches // 1))
        fmt = '{:' + str(num_digits) + 'd}'
        return '[' + fmt + '/' + fmt.format(num_batches) + ']'


def accuracy(output, target, topk=(1,)):
    r"""Computes the accuracy over the $k$ top predictions for the specified values of k
    """
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        # _, pred = output.topk(maxk, 1, True, True)
        # pred = pred.t()
        # correct = pred.eq(target.view(1, -1).expand_as(pred))

        # faster topk (ref: https://github.com/pytorch/pytorch/issues/22812)
        _, idx = output.sort(descending=True)
        pred = idx[:,:maxk]
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res

# %% [markdown]
# Parameter가 5M 미만이 되도록 Custom한 ResNet 코드입니다.
# 다른 Model을 사용하는 경우 삭제해도 무방합니다.

# %%
efficientnet_b0 = models.efficientnet_b0(pretrained=False)

efficientnet_b0.classifier = nn.Sequential(
    nn.Dropout(0.3),
    nn.Linear(1280, 400)
)

# %% [markdown]
# 위에서 정의한 Model을 만들고 Parameter수를 체크한 후
# 5M 미만인 경우 GPU에서 정상 사용되는지 확인하는 부분입니다.

# %%
# loading the model architecture
model = efficientnet_b0.cuda()

# Check number of parameters your model
pytorch_total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {pytorch_total_params}")
if int(pytorch_total_params) > 5000000:
    print('Your model has the number of parameters more than 5 millions..')
    sys.exit()
    
device = torch.device('cuda:0' if cuda.is_available() else 'cpu')
model.to(device)
print(device)
# Out:
# Number of parameters: 4519948
# cuda:0

# %%
from torchsummary import summary

summary(model, input_size=(3,224,224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 112, 112]             864
#        BatchNorm2d-2         [-1, 32, 112, 112]              64
#               SiLU-3         [-1, 32, 112, 112]               0
#             Conv2d-4         [-1, 32, 112, 112]             288
#        BatchNorm2d-5         [-1, 32, 112, 112]              64
#               SiLU-6         [-1, 32, 112, 112]               0
#  AdaptiveAvgPool2d-7             [-1, 32, 1, 1]               0
#             Conv2d-8              [-1, 8, 1, 1]             264
#               SiLU-9              [-1, 8, 1, 1]               0
#            Conv2d-10             [-1, 32, 1, 1]             288
#           Sigmoid-11             [-1, 32, 1, 1]               0
# SqueezeExcitation-12         [-1, 32, 112, 112]               0
#            Conv2d-13         [-1, 16, 112, 112]             512
#       BatchNorm2d-14         [-1, 16, 112, 112]              32
#            MBConv-15         [-1, 16, 112, 112]               0
#            Conv2d-16         [-1, 96, 112, 112]           1,536
#       BatchNorm2d-17         [-1, 96, 112, 112]             192
#              SiLU-18         [-1, 96, 112, 112]               0
#            Conv2d-19           [-1, 96, 56, 56]             864
#       BatchNorm2d-20           [-1, 96, 56, 56]             192
#           Conv2d-187           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-188           [-1, 1152, 7, 7]           2,304
#             SiLU-189           [-1, 1152, 7, 7]               0
#           Conv2d-190           [-1, 1152, 7, 7]          28,800
#      BatchNorm2d-191           [-1, 1152, 7, 7]           2,304
#             SiLU-192           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-193           [-1, 1152, 1, 1]               0
#           Conv2d-194             [-1, 48, 1, 1]          55,344
#             SiLU-195             [-1, 48, 1, 1]               0
#           Conv2d-196           [-1, 1152, 1, 1]          56,448
#          Sigmoid-197           [-1, 1152, 1, 1]               0
# SqueezeExcitation-198           [-1, 1152, 7, 7]               0
#           Conv2d-199            [-1, 192, 7, 7]         221,184
#      BatchNorm2d-200            [-1, 192, 7, 7]             384
#  StochasticDepth-201            [-1, 192, 7, 7]               0
#           MBConv-202            [-1, 192, 7, 7]               0
#           Conv2d-203           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-204           [-1, 1152, 7, 7]           2,304
#             SiLU-205           [-1, 1152, 7, 7]               0
#           Conv2d-206           [-1, 1152, 7, 7]          28,800
#      BatchNorm2d-207           [-1, 1152, 7, 7]           2,304
#             SiLU-208           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-209           [-1, 1152, 1, 1]               0
#           Conv2d-210             [-1, 48, 1, 1]          55,344
#             SiLU-211             [-1, 48, 1, 1]               0
#           Conv2d-212           [-1, 1152, 1, 1]          56,448
#          Sigmoid-213           [-1, 1152, 1, 1]               0
# SqueezeExcitation-214           [-1, 1152, 7, 7]               0
#           Conv2d-215            [-1, 192, 7, 7]         221,184
#      BatchNorm2d-216            [-1, 192, 7, 7]             384
#  StochasticDepth-217            [-1, 192, 7, 7]               0
#           MBConv-218            [-1, 192, 7, 7]               0
#           Conv2d-219           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-220           [-1, 1152, 7, 7]           2,304
#             SiLU-221           [-1, 1152, 7, 7]               0
#           Conv2d-222           [-1, 1152, 7, 7]          28,800
#      BatchNorm2d-223           [-1, 1152, 7, 7]           2,304
#             SiLU-224           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-225           [-1, 1152, 1, 1]               0
#           Conv2d-226             [-1, 48, 1, 1]          55,344
#             SiLU-227             [-1, 48, 1, 1]               0
#           Conv2d-228           [-1, 1152, 1, 1]          56,448
#          Sigmoid-229           [-1, 1152, 1, 1]               0
# SqueezeExcitation-230           [-1, 1152, 7, 7]               0
#           Conv2d-231            [-1, 192, 7, 7]         221,184
#      BatchNorm2d-232            [-1, 192, 7, 7]             384
#  StochasticDepth-233            [-1, 192, 7, 7]               0
#           MBConv-234            [-1, 192, 7, 7]               0
#           Conv2d-235           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-236           [-1, 1152, 7, 7]           2,304
#             SiLU-237           [-1, 1152, 7, 7]               0
#           Conv2d-238           [-1, 1152, 7, 7]          10,368
#      BatchNorm2d-239           [-1, 1152, 7, 7]           2,304
#             SiLU-240           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-241           [-1, 1152, 1, 1]               0
#           Conv2d-242             [-1, 48, 1, 1]          55,344
#             SiLU-243             [-1, 48, 1, 1]               0
#           Conv2d-244           [-1, 1152, 1, 1]          56,448
#          Sigmoid-245           [-1, 1152, 1, 1]               0
# SqueezeExcitation-246           [-1, 1152, 7, 7]               0
#           Conv2d-247            [-1, 320, 7, 7]         368,640
#      BatchNorm2d-248            [-1, 320, 7, 7]             640
#           MBConv-249            [-1, 320, 7, 7]               0
#           Conv2d-250           [-1, 1280, 7, 7]         409,600
#      BatchNorm2d-251           [-1, 1280, 7, 7]           2,560
#             SiLU-252           [-1, 1280, 7, 7]               0
# AdaptiveAvgPool2d-253           [-1, 1280, 1, 1]               0
#          Dropout-254                 [-1, 1280]               0
#           Linear-255                  [-1, 400]         512,400
# ================================================================
# Total params: 4,519,948
# Trainable params: 4,519,948
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 173.65
# Params size (MB): 17.24
# Estimated Total Size (MB): 191.46
# ----------------------------------------------------------------

# %% [markdown]
# Train Data를 불러와 Train set/Validation set으로 구분한 후
# 각 Data에 Augmentation 기법을 적용하는 부분입니다.

# %%
# doing data augmentation 
train_transform = transforms.Compose([transforms.Resize((224,224)),
                                      transforms.RandomRotation(45),
                                      transforms.RandomVerticalFlip(),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                      ])
val_transform = transforms.Compose([transforms.Resize((224,224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# %%
# splitting the data into train/validation/test sets
data = datasets.ImageFolder(data_dir)
train_size = int(len(data)*0.9)
val_size = int((len(data)-train_size))
train_data, val_data = random_split(data,[train_size,val_size])
torch.manual_seed(3334)
print(f'train size: {len(train_data)}\nval size: {len(val_data)}')

train_data.dataset.transform = train_transform
val_data.dataset.transform = val_transform
batch_size = 128
train_loader = DataLoader(train_data,batch_size=batch_size,shuffle=True, num_workers=4)
val_loader = DataLoader(val_data,batch_size=batch_size,shuffle=True, num_workers=4)
# Out:
# train size: 131749
# val size: 14639

# %%
batch_iterator = iter(train_loader)
images = next(batch_iterator)

images[0].shape
# Out:
# torch.Size([128, 3, 224, 224])

# %% [markdown]
# Loss Function과 Optimizer를 선언하는 부분입니다.
# 다양한 Loss와 Optimizer를 통해 성능을 올려보세요!

# %%
import math
from torch.optim.lr_scheduler import _LRScheduler

class CosineAnnealingWarmUpRestarts(_LRScheduler):
    def __init__(self, optimizer, T_0, T_mult=1, eta_max=0.1, T_up=0, gamma=1., last_epoch=-1):
        if T_0 <= 0 or not isinstance(T_0, int):
            raise ValueError("Expected positive integer T_0, but got {}".format(T_0))
        if T_mult < 1 or not isinstance(T_mult, int):
            raise ValueError("Expected integer T_mult >= 1, but got {}".format(T_mult))
        if T_up < 0 or not isinstance(T_up, int):
            raise ValueError("Expected positive integer T_up, but got {}".format(T_up))
        self.T_0 = T_0
        self.T_mult = T_mult
        self.base_eta_max = eta_max
        self.eta_max = eta_max
        self.T_up = T_up
        self.T_i = T_0
        self.gamma = gamma
        self.cycle = 0
        self.T_cur = last_epoch
        super(CosineAnnealingWarmUpRestarts, self).__init__(optimizer, last_epoch)
    
    def get_lr(self):
        if self.T_cur == -1:
            return self.base_lrs
        elif self.T_cur < self.T_up:
            return [(self.eta_max - base_lr)*self.T_cur / self.T_up + base_lr for base_lr in self.base_lrs]
        else:
            return [base_lr + (self.eta_max - base_lr) * (1 + math.cos(math.pi * (self.T_cur-self.T_up) / (self.T_i - self.T_up))) / 2
                    for base_lr in self.base_lrs]

    def step(self, epoch=None):
        if epoch is None:
            epoch = self.last_epoch + 1
            self.T_cur = self.T_cur + 1
            if self.T_cur >= self.T_i:
                self.cycle += 1
                self.T_cur = self.T_cur - self.T_i
                self.T_i = (self.T_i - self.T_up) * self.T_mult + self.T_up
        else:
            if epoch >= self.T_0:
                if self.T_mult == 1:
                    self.T_cur = epoch % self.T_0
                    self.cycle = epoch // self.T_0
                else:
                    n = int(math.log((epoch / self.T_0 * (self.T_mult - 1) + 1), self.T_mult))
                    self.cycle = n
                    self.T_cur = epoch - self.T_0 * (self.T_mult ** n - 1) / (self.T_mult - 1)
                    self.T_i = self.T_0 * self.T_mult ** (n)
            else:
                self.T_i = self.T_0
                self.T_cur = epoch
                
        self.eta_max = self.base_eta_max * (self.gamma**self.cycle)
        self.last_epoch = math.floor(epoch)
        for param_group, lr in zip(self.optimizer.param_groups, self.get_lr()):
            param_group['lr'] = lr

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.RAdam(model.parameters(), lr=0.000001, weight_decay=5e-5)
scheduler = CosineAnnealingWarmUpRestarts(optimizer, T_0=50, T_mult=1, eta_max=0.01,  T_up=12, gamma=1)

# %% [markdown]
# Train 해주는 함수입니다.

# %%
def fit(model,criterion,optimizer,num_epochs=10):
    print_freq = 30
    start = time.time()
    best_model = model.state_dict()
    best_acc = 0
    train_loss_over_time = []
    val_loss_over_time = []
    train_acc_over_time = []
    val_acc_over_time = []


    # each epoch has a training and validation phase
    for epoch in range(num_epochs):
        
        print("\n----- epoch: {}, lr: {} -----".format(epoch, optimizer.param_groups[0]["lr"]))
        batch_time = AverageMeter('Time', ':6.3f')
        acc = AverageMeter('Accuracy', ':.4e')
        progress = ProgressMeter(len(train_loader), batch_time, acc, prefix="Epoch: [{}]".format(epoch))

        for phase in ['train','val']:
            
            if phase == 'train':
                data_loader = train_loader
                model.train()                    # set the model to train mode
                end = time.time()

            else:
                data_loader = val_loader
                model.eval()                    # set the model to evaluate mode
                end = time.time()
            
                
            running_loss = 0.0
            running_corrects = 0.0
            
            # iterate over the data
            for i,(inputs,labels) in enumerate(data_loader):
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                # zero the parameter gradients
                optimizer.zero_grad()
                
                # forward
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _,pred = torch.max(outputs,dim=1)
                    loss = criterion(outputs,labels)
                    
                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                
                # calculating the loss and accuracy
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(pred == labels.data)

                epoch_acc = (running_corrects.double()/len(train_data)).cpu().numpy()
                acc.update(epoch_acc.item(), inputs.size(0))
                
                if phase == 'train':                          
                    batch_time.update(time.time() - end)
                    end = time.time()

                    if i % print_freq == 0:
                        progress.print(i)  

            if phase == 'train':

                epoch_loss = running_loss/len(train_data)
                train_loss_over_time.append(epoch_loss)
                epoch_acc = (running_corrects.double()/len(train_data)).cpu().numpy()
                train_acc_over_time.append(epoch_acc)


            else:
                epoch_loss = running_loss/len(val_data)
                val_loss_over_time.append(epoch_loss)
                epoch_acc = (running_corrects.double()/len(val_data)).cpu().numpy()
                val_acc_over_time.append(epoch_acc)
          

            print(f'{phase} loss: {epoch_loss:.3f}, acc: {epoch_acc:.3f}')
            
            if phase == 'val' and epoch_acc >= best_acc:
                best_acc = epoch_acc
                torch.save(model.state_dict(), '/content/drive/MyDrive/model_best_pleaseplease.pt')
            
            torch.save(model.state_dict(),'model_latest.pt')
            
        scheduler.step() #####

        print('-'*60)
    print('\n') 
    elapsed_time = time.time() - start
    print('==> {:.2f} seconds to train this epoch\n'.format(elapsed_time))
    print(f'best accuracy: {best_acc:.3f}')


    # load best model weights
    model.load_state_dict(best_model)
    loss = {'train':train_loss_over_time, 'val':val_loss_over_time}
    acc = {'train':train_acc_over_time, 'val':val_acc_over_time}

    return model,loss, acc

# %% [markdown]
# Train 함수를 통해 Epoch수만큼 학습하는 부분입니다.

# %%
# training the model
# trained for 5 epochs then for 3 epochs then 2
epochs = 50
history, loss, acc = fit(model, criterion, optimizer, num_epochs = epochs)
# Out:
# ----- epoch: 0, lr: 1e-06 -----
# Epoch: [0][   0/1030]	Time  1.812 ( 1.812)	Accuracy 0.0000e+00 (0.0000e+00)
# Epoch: [0][  30/1030]	Time  0.483 ( 0.523)	Accuracy 4.5541e-05 (3.0850e-05)
# Epoch: [0][  60/1030]	Time  0.479 ( 0.502)	Accuracy 1.4421e-04 (6.9307e-05)
# Epoch: [0][  90/1030]	Time  0.485 ( 0.495)	Accuracy 2.3530e-04 (1.0359e-04)
# Epoch: [0][ 120/1030]	Time  0.480 ( 0.491)	Accuracy 3.1879e-04 (1.4628e-04)
# Epoch: [0][ 150/1030]	Time  0.479 ( 0.489)	Accuracy 3.9469e-04 (1.8659e-04)
# Epoch: [0][ 180/1030]	Time  0.479 ( 0.488)	Accuracy 4.8577e-04 (2.3005e-04)
# Epoch: [0][ 210/1030]	Time  0.480 ( 0.487)	Accuracy 5.6926e-04 (2.7062e-04)
# Epoch: [0][ 240/1030]	Time  0.479 ( 0.486)	Accuracy 6.1481e-04 (3.1044e-04)
# Epoch: [0][ 270/1030]	Time  0.479 ( 0.486)	Accuracy 6.9071e-04 (3.4918e-04)
# Epoch: [0][ 300/1030]	Time  0.479 ( 0.485)	Accuracy 7.4384e-04 (3.8637e-04)
# Epoch: [0][ 330/1030]	Time  0.479 ( 0.485)	Accuracy 7.9697e-04 (4.2207e-04)
# Epoch: [0][ 360/1030]	Time  0.479 ( 0.485)	Accuracy 8.7287e-04 (4.5592e-04)
# Epoch: [0][ 390/1030]	Time  0.480 ( 0.484)	Accuracy 9.7913e-04 (4.9167e-04)
# Epoch: [0][ 420/1030]	Time  0.481 ( 0.484)	Accuracy 1.0702e-03 (5.2917e-04)
# Epoch: [49][ 240/1030]	Time  0.488 ( 0.488)	Accuracy 2.3373e-01 (1.1734e-01)
# Epoch: [49][ 270/1030]	Time  0.485 ( 0.488)	Accuracy 2.6283e-01 (1.3189e-01)
# Epoch: [49][ 300/1030]	Time  0.483 ( 0.488)	Accuracy 2.9192e-01 (1.4644e-01)
# Epoch: [49][ 330/1030]	Time  0.500 ( 0.488)	Accuracy 3.2103e-01 (1.6099e-01)
# Epoch: [49][ 360/1030]	Time  0.483 ( 0.487)	Accuracy 3.5012e-01 (1.7554e-01)
# Epoch: [49][ 390/1030]	Time  0.484 ( 0.487)	Accuracy 3.7920e-01 (1.9009e-01)
# Epoch: [49][ 420/1030]	Time  0.490 ( 0.487)	Accuracy 4.0830e-01 (2.0463e-01)
# Epoch: [49][ 450/1030]	Time  0.482 ( 0.487)	Accuracy 4.3738e-01 (2.1918e-01)
# Epoch: [49][ 480/1030]	Time  0.484 ( 0.487)	Accuracy 4.6651e-01 (2.3373e-01)
# Epoch: [49][ 510/1030]	Time  0.484 ( 0.487)	Accuracy 4.9559e-01 (2.4828e-01)
# Epoch: [49][ 540/1030]	Time  0.485 ( 0.487)	Accuracy 5.2467e-01 (2.6282e-01)
# Epoch: [49][ 570/1030]	Time  0.482 ( 0.486)	Accuracy 5.5376e-01 (2.7737e-01)
# Epoch: [49][ 600/1030]	Time  0.483 ( 0.486)	Accuracy 5.8284e-01 (2.9192e-01)
# Epoch: [49][ 630/1030]	Time  0.485 ( 0.486)	Accuracy 6.1198e-01 (3.0647e-01)
# Epoch: [49][ 660/1030]	Time  0.484 ( 0.486)	Accuracy 6.4108e-01 (3.2101e-01)
# Epoch: [49][ 690/1030]	Time  0.487 ( 0.486)	Accuracy 6.7021e-01 (3.3556e-01)
# Epoch: [49][ 720/1030]	Time  0.486 ( 0.486)	Accuracy 6.9925e-01 (3.5011e-01)
# Epoch: [49][ 750/1030]	Time  0.484 ( 0.486)	Accuracy 7.2835e-01 (3.6466e-01)
# Epoch: [49][ 780/1030]	Time  0.486 ( 0.486)	Accuracy 7.5745e-01 (3.7921e-01)
# Epoch: [49][ 810/1030]	Time  0.483 ( 0.486)	Accuracy 7.8654e-01 (3.9376e-01)
# Epoch: [49][ 840/1030]	Time  0.482 ( 0.486)	Accuracy 8.1562e-01 (4.0830e-01)
# Epoch: [49][ 870/1030]	Time  0.483 ( 0.486)	Accuracy 8.4469e-01 (4.2285e-01)
# Epoch: [49][ 900/1030]	Time  0.485 ( 0.486)	Accuracy 8.7378e-01 (4.3739e-01)
# Epoch: [49][ 930/1030]	Time  0.484 ( 0.486)	Accuracy 9.0289e-01 (4.5194e-01)
# Epoch: [49][ 960/1030]	Time  0.493 ( 0.486)	Accuracy 9.3199e-01 (4.6649e-01)
# Epoch: [49][ 990/1030]	Time  0.485 ( 0.486)	Accuracy 9.6108e-01 (4.8103e-01)
# Epoch: [49][1020/1030]	Time  0.484 ( 0.486)	Accuracy 9.9022e-01 (4.9558e-01)
# train loss: 0.021, acc: 0.998
# val loss: 0.063, acc: 0.985
# ------------------------------------------------------------
#
#
# ==> 25925.63 seconds to train this epoch
#
# best accuracy: 0.985

# %% [markdown]
# Train결과로 나온 정확도와 Loss가 몇 Epoch에서 최적인지 볼 수 있도록 구성해놓은 Plotting 부분입니다.

# %%
# plotting the loss and accuracy curve for each phase
train_loss = loss['train']
val_loss = loss['val']
train_acc = acc['train']
val_acc = acc['val']

epochs_range = range(epochs)

plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
plt.ylim(0,10)
plt.xlim(0,50)
plt.plot(epochs_range, train_loss, label='train_loss')
plt.plot(epochs_range, val_loss, label='val_loss')
plt.legend(loc=0)
plt.title('Loss')

plt.subplot(1,2,2)
plt.plot(epochs_range, train_acc ,label='train_acc')
plt.plot(epochs_range, val_acc, label='val_acc')
plt.legend(loc=0)
plt.ylim(0,1)
plt.xlim(0,50)
plt.title('Accuracy')
# Out:
# Text(0.5, 1.0, 'Accuracy')

# %% [markdown]
# Test Dataset을 불러오는 부분입니다.

# %%
seed = 0
torch.manual_seed(seed)
if cuda:
    torch.cuda.manual_seed(seed)

torch.manual_seed(3334)
test_transform = transforms.Compose([transforms.Resize((224,224)),transforms.ToTensor(),
                                    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# splitting the data into train/validation/test sets
test_data_dir = '/content/dataset/test'
_data = datasets.ImageFolder(test_data_dir)
test1_size = int(len(_data)*1)
test2_size = int((len(_data)-test1_size))
test_data, test2_data = torch.utils.data.random_split(_data,[test1_size, test2_size])
torch.manual_seed(3334)

print(f'test size: {len(test_data)}')

test_data.dataset.transform = test_transform
batch_size = 128
test_loader = DataLoader(test_data, batch_size = batch_size, shuffle = False)
print(test_loader)
# Out:
# test size: 2000
# <torch.utils.data.dataloader.DataLoader object at 0x7f7750caa590>

# %% [markdown]
# 앞에서 훈련 시킨 Model중 가장 높은 정확도를 가진 모델을 불러와 Test Dataset에 대한 결과를 만들어주는 부분으로 이 코드는 변경하지 않아도 됩니다.

# %%
import itertools
# testing how good the model is
def evaluate(model,criterion):
    model.eval()       # setting the model to evaluate mode
    preds = []
    Category = []
    corrects = 0 #####

    test_model = efficientnet_b0.cuda()
    #저장경로는 변경하셔도 됩니다.
    test_model.load_state_dict(torch.load('/content/drive/MyDrive/model_best_pleaseplease.pt'))

    for inputs, label_ in test_loader:
        
        inputs = inputs.to(device)
        labels = label_.to(device)
        # predicting
        with torch.no_grad():

            outputs = test_model(inputs)
            _,pred = torch.max(outputs,dim=1)
            preds.append(pred)

            corrects += torch.sum(pred == labels.data) #####

    acc = (corrects.double()/2000).cpu().numpy() #####

    category = [t.cpu().numpy() for t in preds]
    
    t_category = list(itertools.chain(*category))
   
    Id = list(range(0, len(t_category)))

    prediction = {
      'Id': Id,
      'Category': t_category 
    }

    prediction_df = pd.DataFrame(prediction, columns=['Id','Category'])
    #저장경로는 변경하셔도 됩니다.
    prediction_df.to_csv('/content/drive/MyDrive/model_best_pleaseplease.csv', index=False)
    print(acc)
    print('Done!!')
        
    return preds

# testing the model
predictions = evaluate(model, criterion)
# Out:
# 0.99
# Done!!
